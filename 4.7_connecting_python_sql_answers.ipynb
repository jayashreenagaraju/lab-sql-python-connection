# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SQL-Alchemy" data-toc-modified-id="SQL-Alchemy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SQL Alchemy</a></span><ul class="toc-item"><li><span><a href="#Installation" data-toc-modified-id="Installation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Installation</a></span><ul class="toc-item"><li><span><a href="#Option-1" data-toc-modified-id="Option-1-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Option 1</a></span></li><li><span><a href="#Option-2" data-toc-modified-id="Option-2-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Option 2</a></span></li><li><span><a href="#Option-3" data-toc-modified-id="Option-3-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Option 3</a></span></li><li><span><a href="#Important-Note" data-toc-modified-id="Important-Note-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Important Note</a></span></li></ul></li><li><span><a href="#What-is-SQL-Alchemy" data-toc-modified-id="What-is-SQL-Alchemy-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>What is SQL Alchemy</a></span></li><li><span><a href="#Creating-the-engine" data-toc-modified-id="Creating-the-engine-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Creating the engine</a></span></li><li><span><a href="#Getting-a-connection" data-toc-modified-id="Getting-a-connection-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Getting a connection</a></span></li><li><span><a href="#Running-queries" data-toc-modified-id="Running-queries-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Running queries</a></span><ul class="toc-item"><li><span><a href="#Running-Raw-Queries" data-toc-modified-id="Running-Raw-Queries-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Running Raw Queries</a></span></li><li><span><a href="#Getting-data-from-the-result" data-toc-modified-id="Getting-data-from-the-result-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Getting data from the result</a></span><ul class="toc-item"><li><span><a href="#Getting-the-first-row" data-toc-modified-id="Getting-the-first-row-1.5.2.1"><span class="toc-item-num">1.5.2.1&nbsp;&nbsp;</span>Getting the first row</a></span></li><li><span><a href="#Get-all-rows" data-toc-modified-id="Get-all-rows-1.5.2.2"><span class="toc-item-num">1.5.2.2&nbsp;&nbsp;</span>Get all rows</a></span></li><li><span><a href="#Iterate-through-the-first-column" data-toc-modified-id="Iterate-through-the-first-column-1.5.2.3"><span class="toc-item-num">1.5.2.3&nbsp;&nbsp;</span>Iterate through the first column</a></span></li><li><span><a href="#Getting-the-first-column-in-a-list" data-toc-modified-id="Getting-the-first-column-in-a-list-1.5.2.4"><span class="toc-item-num">1.5.2.4&nbsp;&nbsp;</span>Getting the first column in a list</a></span></li></ul></li><li><span><a href="#Using-it-as-ORM" data-toc-modified-id="Using-it-as-ORM-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Using it as ORM</a></span></li><li><span><a href="#More-examples-on-raw-queries" data-toc-modified-id="More-examples-on-raw-queries-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>More examples on raw queries</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#CFU" data-toc-modified-id="CFU-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>CFU</a></span></li></ul></li><li><span><a href="#Bonus:-MySQL-Connector" data-toc-modified-id="Bonus:-MySQL-Connector-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Bonus: MySQL Connector</a></span><ul class="toc-item"><li><span><a href="#Installation:" data-toc-modified-id="Installation:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Installation:</a></span></li><li><span><a href="#Establishing-a-Connection:" data-toc-modified-id="Establishing-a-Connection:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Establishing a Connection:</a></span></li><li><span><a href="#Creating-a-Cursor:" data-toc-modified-id="Creating-a-Cursor:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Creating a Cursor:</a></span></li><li><span><a href="#Executing-SQL-Queries:" data-toc-modified-id="Executing-SQL-Queries:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Executing SQL Queries:</a></span><ul class="toc-item"><li><span><a href="#Example:-CoffeeShop-DB-📒☕" data-toc-modified-id="Example:-CoffeeShop-DB-📒☕-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Example: CoffeeShop DB 📒☕</a></span></li></ul></li><li><span><a href="#Closing-the-Connection:" data-toc-modified-id="Closing-the-Connection:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Closing the Connection:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # SQL Alchemy

# %% [markdown]
# ## Installation

# %% [markdown]
# For this lesson, you must install the libraries `SQLAlchemy` and `PyMySql` on your computers.
# There are several ways to do this installation:
#
# ### Option 1
#
# - Open a new Jupyter notebook
# - Open a new code cell and type:
#
# ```shell
# !conda install sqlalchemy -y
# ```
#
# or if you're using pip+venv
#
# ```shell
# !pip install sqlalchemy
# ```
#
# - Open a new code cell and type:
#
# ```shell
# !conda install pymysql -y
# ```
#
# or if you're using pip+venv
#
# ```shell
# !pip install pymysql
# ```
#
# ### Option 2
#
# Alternatively you can go to the `Anaconda navigator`, and click on the `Environments` section on the left panel. Then:
#
# - On the search bar type: `sqlalchemy`
# - If this library doesn't appear as installed click on the checkbox and then on `Apply`, accept the `dependencies` and wait until the system installs the library
# - On the search bar type: `pymysql`
# - If this library doesn't appear as installed click on the checkbox and then on `Apply`, accept the `dependencies` and wait until the system installs the library
#
# ### Option 3
#
# ❗️ If you use this third option, you will first have to save and close your Jupyter notebook, then run the instructions below and open again the Jupyter notebook.
#
#
# - Open a new terminal (MacOS/Linux) or the Anaconda Powershell prompt and type
#
# ```shell
# conda install sqlalchemy -y
# ```
#
# or if you're using pip+venv, **make sure that you have your venv environment activated and type:**
#
# ```shell
# pip install sqlalchemy
# ```
#
# - Open a new code cell and type:
#
# ```shell
# conda install pymysql -y
# ```
#
# or if you're using pip+venv **make sure that you have your venv environment activated and type:**
#
# ```shell
# pip install pymysql
# ```

# %%
# !conda install pymysql -y

# %% [markdown]
# ### Important Note
#
#
# **Upgrading to SQLAlchemy Version 2.0**:
#
# The new version 2.0 of SQLAlchemy introduces significant API changes compared to the 1.4 series. Given these changes, it's crucial to ensure you have the latest version installed, especially if you plan to follow along with classes or tutorials that use the newest features of the library.
#
# To get started, follow these steps:
#
# 1. **Check Your Current Version**:
#    Before making any changes, it's wise to check your currently installed version of SQLAlchemy.
#
#    If you're using conda as a package manager:
#
#    ```bash
#    conda list sqlalchemy | tail -1 | awk '{print $2}'
#    ```
#
#    If you're using pip as a package manager:
#
#    ```bash
#    pip show sqlalchemy | grep Version
#    ```
#
#
# 2. **Upgrade to Version 2.0 (if necessary)**:
#    If your current version is in the 1.x series instead of 2.x, you should upgrade to the latest version.
#
#    If you're using conda:
#
#    ```bash
#    conda update sqlalchemy
#    ```
#
#    If you're using pip:
#
#    ```bash
#    pip install --upgrade sqlalchemy
#    ```

# %%
# !conda update sqlalchemy -y
# Out:
# blinker-1.7.0        | 17 KB     |                                       |   0%
# ncurses-6.4          | 803 KB    |                                       |   0%
#
# lz4-4.3.3            | 36 KB     |                                       |   0%
#
#
# ptyprocess-0.7.0     | 16 KB     |                                       |   0%
#
#
#
# lxml-5.1.0           | 1.2 MB    |                                       |   0%
#
#
#
#
# seaborn-0.13.2       | 7 KB      |                                       |   0%
#
#
#
#
#
# nltk-3.8.1           | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   |                                       |   0%
#
#
#
#
#
#
#
# yarl-1.9.4           | 110 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 50 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# scrapy-2.11.1        | 974 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# mistune-3.0.2        | 64 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# appscript-1.2.5      | 167 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1010 KB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 89 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-17.0.6   | 293 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.0      | 27 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 26 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.2     | 26 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-lsp-server-1. | 7 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.16.3 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# constantly-15.1.0    | 9 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# lxml-5.1.0           | 1.2 MB    | 4                                     |   1%
#
#
# blinker-1.7.0        | 17 KB     | #################################8    |  92%
#
# lz4-4.3.3            | 36 KB     | ################4                     |  44%
# ncurses-6.4          | 803 KB    | 7                                     |   2%
#
#
# ptyprocess-0.7.0     | 16 KB     | ##################################### | 100%
#
#
#
#
# seaborn-0.13.2       | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
# blinker-1.7.0        | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   |                                       |   0%
#
#
#
#
#
# nltk-3.8.1           | 1.0 MB    | 5                                     |   2%
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 50 KB     | ###########8                          |  32%
#
# lz4-4.3.3            | 36 KB     | ##################################### | 100%
#
# lz4-4.3.3            | 36 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# mistune-3.0.2        | 64 KB     | #########1                            |  25%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
#
# scrapy-2.11.1        | 974 KB    | 6                                     |   2%
#
#
#
#
# seaborn-0.13.2       | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 89 KB     | ######6                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# appscript-1.2.5      | 167 KB    | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1010 KB   | 5                                     |   2%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-17.0.6   | 293 KB    | ##                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.0      | 27 KB     | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 26 KB     | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.2     | 26 KB     | #######################1              |  63%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | ################9                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-lsp-server-1. | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    | ####8                                 |  13%
#
#
#
#
#
#
#
# yarl-1.9.4           | 110 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# constantly-15.1.0    | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.16.3 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
# yarl-1.9.4           | 110 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    | ###########4                          |  31%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | #####################9                |  59%
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# libffi-3.4.2         | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    | #######################5              |  64%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    | #################################6    |  91%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | ###################################   |  95%
#
#
#
# lxml-5.1.0           | 1.2 MB    | ##################################### | 100%
#
#
#
# lxml-5.1.0           | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# mistune-3.0.2        | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# mistune-3.0.2        | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 89 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 89 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# appscript-1.2.5      | 167 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# appscript-1.2.5      | 167 KB    | ##################################### | 100%
#
#
#
#
#
# nltk-3.8.1           | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
# nltk-3.8.1           | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# scrapy-2.11.1        | 974 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# scrapy-2.11.1        | 974 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.0      | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.0      | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-17.0.6   | 293 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-17.0.6   | 293 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-7 | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.2     | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.6.2     | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-lsp-server-1. | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# constantly-15.1.0    | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.16.3 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.16.3 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1010 KB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1010 KB   | ##################################### | 100%
# ncurses-6.4          | 803 KB    | ##################################### | 100%
# ncurses-6.4          | 803 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.12   | 8.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# pandas-2.2.1         | 14.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda list sqlalchemy | tail -1 | awk '{print $2}'

# %% [markdown]
# ## What is SQL Alchemy

# %% [markdown]
# SQLAlchemy is a popular SQL toolkit and Object-Relational Mapping (ORM) library for Python. It provides a set of high-level APIs to connect to relational databases. Using SQLAlchemy, you can work with relational databases in a more Pythonic way, abstracting away many of the common database operations. Here's a breakdown of its main features:
#
# 1. **ORM (Object-Relational Mapping)**:
#    - Allows classes to be mapped to database tables, so you can use Python objects to represent database rows.
#    - Provides a high-level, abstracted pattern for CRUD (Create, Read, Update, Delete) operations.
#    - Automates the process of synchronizing object states with database content.
#
# 2. **SQL Expression Language**:
#    - A comprehensive SQL abstraction tool that allows you to build SQL queries using Python expressions.
#    - Gives you the power and flexibility of raw SQL, but in a more Pythonic way.
#
# 3. **Engine**:
#    - Provides a source of connectivity to a database, which can be fine-tuned for the specific database dialect.
#    - Manages connection pooling, which is crucial for scalable applications.
#
# 4. **Dialects**:
#    - SQLAlchemy supports a variety of database backends by using dialects. Commonly used database systems like PostgreSQL, MySQL, SQLite, and Oracle have their own dialects in SQLAlchemy.
#
# 5. **Schema and Types**:
#    - SQLAlchemy provides a way to declare table structures and relationships directly in Python, which can then be used to automatically create (or drop) database structures.
#    - Offers a broad set of SQL standard and vendor-specific datatypes.
#
# 6. **Session**:
#    - Manages the persistence operations for ORM-mapped objects.
#    - Acts as a transactional buffer, accumulating changes and flushing them to the database in a batch.

# %% [markdown]
# ## Creating the engine

# %% [markdown]
# **Connecting to a Database using SQLAlchemy**:
#
# To connect to a database, we need to set up an SQLAlchemy "engine". Think of this engine as a bridge or gateway between your Python application and the actual database.
#
# The SQLAlchemy engine provides a standard way to interact with the database and execute SQL statements. It achieves this by managing a set of database connections and using a "dialect" specific to your database.

# %% [markdown]
# To get an engine, we use:
#
# ```python
# sqlalchemy.create_engine(connection_string)
# ```
#
# To create the *connection string*, this is the general syntax **`'dialect+driver://username:password@host:port/database'`**

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input
password = getpass.getpass()

# Note that when you use _SQLAlchemy_ and establish the connection, you do not even need to be logged in Sequel Pro or MySQL Workbench.
# Out:
#  ········

# %%
bd = "bank" 
connection_string = 'mysql+pymysql://root:' + password + '@localhost/'+bd
engine = create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/bank)

# %% [markdown]
# This password policy is used only for illustrative purposes and to be simple. However, we shouldn't store the password in the Jupyter notebook variable. There are other safer ways to do this as shown [here](https://towardsdatascience.com/keeping-credentials-safe-in-jupyter-notebooks-fbd215a8e311) and [here](https://dadoverflow.com/2019/08/09/how-do-you-hide-secrets-in-jupyter-notebooks/)

# %% [markdown]
# ## Getting a connection

# %% [markdown]
# We get a connection using the `connect()` method.

# %% [markdown]
# ```python
# connection = engine.connect()
# ```

# %% [markdown]
# It's better practice though to use context managers to manage the connect/release process:
#
# ```python
# with engine.connect() as connection:
#     ...
#
# ```

# %% [markdown]
# ## Running queries

# %% [markdown]
# The SQLAlchemy Connection features an `.execute()` method that will run queries.

# %% [markdown]
# ```python
# with engine.connect() as connection:
#     connection.execute(...)
#     ...
#
# ```

# %% [markdown]
# The `Connection.execute()` always returns a `sqlalchemy.engine.Result` object.

# %% [markdown]
# ### Running Raw Queries

# %% [markdown]
# To invoke a textual query, use the `sqlalchemy.text()` passed to `.execute()`.

# %%
from sqlalchemy import text

with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)

result

# %% [markdown]
# In this specific case the `Result` its called `CursorResult`.
#
# The `Result` object has many methods we can use. Let's look at some of them.

# %% [markdown]
# ### Getting data from the result

# %% [markdown]
# #### Getting the first row
#
# - `.first()`: returns the first row and closes the result set. The row is a `sqlaclhemy.engine.Row` object.
#
# The `Row` object looks and acts mostly like a named tuple:

# %%
row = result.first()

# %%
type(row)
# Out:
# sqlalchemy.engine.row.Row

# %%
row # Looks like a tuple
# Out:
# (5314, 1787, 930705, 96396, 12, 8033.0, 'B')

# %%
row[0] # It has indexes
# Out:
# 5314

# %%
row.loan_id # Its like a named tuple, we can access it column-wise
# Out:
# 5314

# %%
row._mapping # It also has a dictionary interface available via an accessor called ._mapping
# Out:
# {'loan_id': 5314, 'account_id': 1787, 'date': 930705, 'amount': 96396, 'duration': 12, 'payments': 8033.0, 'status': 'B'}

# %%
row._mapping["loan_id"] # Getting a column value dictionary-wise
# Out:
# 5314

# %% [markdown]
# **Note**: if we were to call another method on result, we might encounter an error. To avoid errors:
#
# - Ensure that you're not trying to fetch rows from the result object more than once.
# - If you're using a context for the connection, make sure all operations related to the result object are done within that context.

# %% [markdown]
# #### Get all rows

# %% [markdown]
# Let's look at different ways of getting all rows from a query.

# %%
# We can loop over result.mappings(), and we'll see that we get dictionaries for each row,
# where the key in each dictionary represents the column name. This makes it easy for us to retrieve the data
# and display it in a loop.

with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    for row in result.mappings():
        print(row)
# Out:
# {'loan_id': 5314, 'account_id': 1787, 'date': 930705, 'amount': 96396, 'duration': 12, 'payments': 8033.0, 'status': 'B'}
# {'loan_id': 5316, 'account_id': 1801, 'date': 930711, 'amount': 165960, 'duration': 36, 'payments': 4610.0, 'status': 'A'}
# {'loan_id': 6863, 'account_id': 9188, 'date': 930728, 'amount': 127080, 'duration': 60, 'payments': 2118.0, 'status': 'A'}
# {'loan_id': 5325, 'account_id': 1843, 'date': 930803, 'amount': 105804, 'duration': 36, 'payments': 2939.0, 'status': 'A'}
# {'loan_id': 7240, 'account_id': 11013, 'date': 930906, 'amount': 274740, 'duration': 60, 'payments': 4579.0, 'status': 'A'}
# {'loan_id': 6687, 'account_id': 8261, 'date': 930913, 'amount': 87840, 'duration': 24, 'payments': 3660.0, 'status': 'A'}
# {'loan_id': 7284, 'account_id': 11265, 'date': 930915, 'amount': 52788, 'duration': 12, 'payments': 4399.0, 'status': 'A'}
# {'loan_id': 6111, 'account_id': 5428, 'date': 930924, 'amount': 174744, 'duration': 24, 'payments': 7281.0, 'status': 'B'}
# {'loan_id': 7235, 'account_id': 10973, 'date': 931013, 'amount': 154416, 'duration': 48, 'payments': 3217.0, 'status': 'A'}
# {'loan_id': 5997, 'account_id': 4894, 'date': 931104, 'amount': 117024, 'duration': 24, 'payments': 4876.0, 'status': 'A'}
# {'loan_id': 7121, 'account_id': 10364, 'date': 931110, 'amount': 21924, 'duration': 36, 'payments': 609.0, 'status': 'A'}
# {'loan_id': 6077, 'account_id': 5270, 'date': 931122, 'amount': 79608, 'duration': 24, 'payments': 3317.0, 'status': 'A'}
# {'loan_id': 6228, 'account_id': 6034, 'date': 931201, 'amount': 464520, 'duration': 60, 'payments': 7742.0, 'status': 'B'}
# {'loan_id': 6356, 'account_id': 6701, 'date': 931208, 'amount': 95400, 'duration': 36, 'payments': 2650.0, 'status': 'A'}
# {'loan_id': 5523, 'account_id': 2705, 'date': 931208, 'amount': 93888, 'duration': 36, 'payments': 2608.0, 'status': 'A'}
# {'loan_id': 6456, 'account_id': 7123, 'date': 931209, 'amount': 47016, 'duration': 12, 'payments': 3918.0, 'status': 'A'}
# {'loan_id': 7104, 'account_id': 10320, 'date': 931213, 'amount': 259740, 'duration': 60, 'payments': 4329.0, 'status': 'A'}
# {'loan_id': 6820, 'account_id': 9034, 'date': 931216, 'amount': 38148, 'duration': 12, 'payments': 3179.0, 'status': 'A'}
# {'loan_id': 6876, 'account_id': 9236, 'date': 931221, 'amount': 86616, 'duration': 12, 'payments': 7218.0, 'status': 'A'}
# {'loan_id': 7097, 'account_id': 10266, 'date': 931223, 'amount': 75624, 'duration': 24, 'payments': 3151.0, 'status': 'B'}
# {'loan_id': 4959, 'account_id': 2, 'date': 940105, 'amount': 80952, 'duration': 24, 'payments': 3373.0, 'status': 'A'}
# {'loan_id': 6499, 'account_id': 7401, 'date': 940105, 'amount': 80952, 'duration': 24, 'payments': 3373.0, 'status': 'A'}
# {'loan_id': 5479, 'account_id': 2486, 'date': 940110, 'amount': 24516, 'duration': 12, 'payments': 2043.0, 'status': 'A'}
# {'loan_id': 5170, 'account_id': 1071, 'date': 940120, 'amount': 253200, 'duration': 60, 'payments': 4220.0, 'status': 'C'}
# {'loan_id': 6721, 'account_id': 8475, 'date': 940121, 'amount': 21072, 'duration': 24, 'payments': 878.0, 'status': 'A'}
# {'loan_id': 7259, 'account_id': 11111, 'date': 940131, 'amount': 108144, 'duration': 36, 'payments': 3004.0, 'status': 'A'}
# {'loan_id': 5285, 'account_id': 1603, 'date': 940206, 'amount': 78936, 'duration': 12, 'payments': 6578.0, 'status': 'A'}
# {'loan_id': 5189, 'account_id': 1166, 'date': 940207, 'amount': 149040, 'duration': 48, 'payments': 3105.0, 'status': 'A'}
# {'loan_id': 6650, 'account_id': 8073, 'date': 940217, 'amount': 49320, 'duration': 12, 'payments': 4110.0, 'status': 'B'}
# {'loan_id': 7226, 'account_id': 10940, 'date': 940223, 'amount': 197748, 'duration': 36, 'payments': 5493.0, 'status': 'A'}
# {'loan_id': 6087, 'account_id': 5313, 'date': 940227, 'amount': 300660, 'duration': 60, 'payments': 5011.0, 'status': 'C'}
# {'loan_id': 7262, 'account_id': 11135, 'date': 940301, 'amount': 182628, 'duration': 36, 'payments': 5073.0, 'status': 'A'}
# {'loan_id': 5519, 'account_id': 2694, 'date': 940308, 'amount': 91632, 'duration': 12, 'payments': 7636.0, 'status': 'A'}
# {'loan_id': 6577, 'account_id': 7753, 'date': 940311, 'amount': 51696, 'duration': 24, 'payments': 2154.0, 'status': 'A'}
# {'loan_id': 6509, 'account_id': 7445, 'date': 940315, 'amount': 55368, 'duration': 24, 'payments': 2307.0, 'status': 'A'}
# {'loan_id': 6520, 'account_id': 7485, 'date': 940316, 'amount': 91200, 'duration': 24, 'payments': 3800.0, 'status': 'A'}
# {'loan_id': 6699, 'account_id': 8330, 'date': 940330, 'amount': 7656, 'duration': 24, 'payments': 319.0, 'status': 'A'}
# {'loan_id': 6336, 'account_id': 6555, 'date': 940331, 'amount': 212400, 'duration': 36, 'payments': 5900.0, 'status': 'A'}
# {'loan_id': 7055, 'account_id': 10079, 'date': 940406, 'amount': 167100, 'duration': 60, 'payments': 2785.0, 'status': 'C'}
# {'loan_id': 6103, 'account_id': 5385, 'date': 940407, 'amount': 149340, 'duration': 60, 'payments': 2489.0, 'status': 'C'}
# {'loan_id': 6202, 'account_id': 5891, 'date': 940418, 'amount': 65184, 'duration': 12, 'payments': 5432.0, 'status': 'A'}
# {'loan_id': 7066, 'account_id': 10131, 'date': 940502, 'amount': 215388, 'duration': 36, 'payments': 5983.0, 'status': 'B'}
# {'loan_id': 6696, 'account_id': 8321, 'date': 940509, 'amount': 89040, 'duration': 60, 'payments': 1484.0, 'status': 'C'}
# {'loan_id': 6072, 'account_id': 5256, 'date': 940510, 'amount': 193968, 'duration': 36, 'payments': 5388.0, 'status': 'A'}
# {'loan_id': 5130, 'account_id': 813, 'date': 940511, 'amount': 24312, 'duration': 12, 'payments': 2026.0, 'status': 'A'}
# {'loan_id': 5568, 'account_id': 2933, 'date': 940517, 'amount': 272520, 'duration': 60, 'payments': 4542.0, 'status': 'C'}
# {'loan_id': 6678, 'account_id': 8173, 'date': 940520, 'amount': 80340, 'duration': 12, 'payments': 6695.0, 'status': 'A'}
# {'loan_id': 6998, 'account_id': 9833, 'date': 940521, 'amount': 97632, 'duration': 12, 'payments': 8136.0, 'status': 'A'}
# {'loan_id': 6580, 'account_id': 7769, 'date': 940522, 'amount': 196080, 'duration': 48, 'payments': 4085.0, 'status': 'A'}
# {'loan_id': 6316, 'account_id': 6473, 'date': 940526, 'amount': 76908, 'duration': 12, 'payments': 6409.0, 'status': 'B'}
# {'loan_id': 6512, 'account_id': 7454, 'date': 940526, 'amount': 63312, 'duration': 48, 'payments': 1319.0, 'status': 'A'}
# {'loan_id': 6407, 'account_id': 6930, 'date': 940526, 'amount': 25944, 'duration': 24, 'payments': 1081.0, 'status': 'A'}
# {'loan_id': 5002, 'account_id': 173, 'date': 940531, 'amount': 104808, 'duration': 12, 'payments': 8734.0, 'status': 'A'}
# {'loan_id': 6647, 'account_id': 8051, 'date': 940601, 'amount': 208320, 'duration': 48, 'payments': 4340.0, 'status': 'A'}
# {'loan_id': 7137, 'account_id': 10439, 'date': 940603, 'amount': 151560, 'duration': 24, 'payments': 6315.0, 'status': 'A'}
# {'loan_id': 6903, 'account_id': 9337, 'date': 940604, 'amount': 52128, 'duration': 24, 'payments': 2172.0, 'status': 'A'}
# {'loan_id': 5918, 'account_id': 4576, 'date': 940604, 'amount': 300204, 'duration': 36, 'payments': 8339.0, 'status': 'A'}
# {'loan_id': 6642, 'account_id': 8027, 'date': 940605, 'amount': 77640, 'duration': 12, 'payments': 6470.0, 'status': 'A'}
# {'loan_id': 6210, 'account_id': 5927, 'date': 940606, 'amount': 87216, 'duration': 48, 'payments': 1817.0, 'status': 'B'}
# {'loan_id': 6279, 'account_id': 6273, 'date': 940607, 'amount': 87360, 'duration': 24, 'payments': 3640.0, 'status': 'A'}
# {'loan_id': 7249, 'account_id': 11065, 'date': 940612, 'amount': 69360, 'duration': 48, 'payments': 1445.0, 'status': 'A'}
# {'loan_id': 6736, 'account_id': 8558, 'date': 940614, 'amount': 288360, 'duration': 60, 'payments': 4806.0, 'status': 'C'}
# {'loan_id': 6112, 'account_id': 5442, 'date': 940617, 'amount': 174744, 'duration': 24, 'payments': 7281.0, 'status': 'B'}
# {'loan_id': 5319, 'account_id': 1811, 'date': 940623, 'amount': 239460, 'duration': 60, 'payments': 3991.0, 'status': 'C'}
# {'loan_id': 6596, 'account_id': 7844, 'date': 940625, 'amount': 91584, 'duration': 24, 'payments': 3816.0, 'status': 'A'}
# {'loan_id': 5837, 'account_id': 4260, 'date': 940629, 'amount': 244560, 'duration': 60, 'payments': 4076.0, 'status': 'C'}
# {'loan_id': 5657, 'account_id': 3354, 'date': 940705, 'amount': 4980, 'duration': 12, 'payments': 415.0, 'status': 'A'}
# {'loan_id': 5533, 'account_id': 2762, 'date': 940705, 'amount': 111384, 'duration': 24, 'payments': 4641.0, 'status': 'A'}
# {'loan_id': 6232, 'account_id': 6051, 'date': 940708, 'amount': 276660, 'duration': 36, 'payments': 7685.0, 'status': 'B'}
# {'loan_id': 6888, 'account_id': 9265, 'date': 940711, 'amount': 39576, 'duration': 12, 'payments': 3298.0, 'status': 'A'}
# {'loan_id': 6066, 'account_id': 5228, 'date': 940711, 'amount': 173808, 'duration': 24, 'payments': 7242.0, 'status': 'A'}
# {'loan_id': 5549, 'account_id': 2824, 'date': 940716, 'amount': 50460, 'duration': 60, 'payments': 841.0, 'status': 'C'}
# {'loan_id': 5060, 'account_id': 426, 'date': 940719, 'amount': 252060, 'duration': 60, 'payments': 4201.0, 'status': 'D'}
# {'loan_id': 6004, 'account_id': 4937, 'date': 940723, 'amount': 143904, 'duration': 24, 'payments': 5996.0, 'status': 'A'}
# {'loan_id': 5126, 'account_id': 790, 'date': 940724, 'amount': 208128, 'duration': 48, 'payments': 4336.0, 'status': 'B'}
# {'loan_id': 7220, 'account_id': 10911, 'date': 940728, 'amount': 131292, 'duration': 36, 'payments': 3647.0, 'status': 'A'}
# {'loan_id': 6668, 'account_id': 8129, 'date': 940730, 'amount': 74736, 'duration': 36, 'payments': 2076.0, 'status': 'A'}
# {'loan_id': 5395, 'account_id': 2176, 'date': 940730, 'amount': 299088, 'duration': 36, 'payments': 8308.0, 'status': 'B'}
# {'loan_id': 6836, 'account_id': 9093, 'date': 940803, 'amount': 189300, 'duration': 60, 'payments': 3155.0, 'status': 'C'}
# {'loan_id': 6064, 'account_id': 5215, 'date': 940804, 'amount': 14628, 'duration': 12, 'payments': 1219.0, 'status': 'A'}
# {'loan_id': 6919, 'account_id': 9403, 'date': 940805, 'amount': 120888, 'duration': 36, 'payments': 3358.0, 'status': 'A'}
# {'loan_id': 6841, 'account_id': 9104, 'date': 940807, 'amount': 172080, 'duration': 48, 'payments': 3585.0, 'status': 'A'}
# {'loan_id': 6038, 'account_id': 5120, 'date': 940810, 'amount': 323472, 'duration': 48, 'payments': 6739.0, 'status': 'A'}
# {'loan_id': 6729, 'account_id': 8519, 'date': 940811, 'amount': 74688, 'duration': 12, 'payments': 6224.0, 'status': 'A'}
# {'loan_id': 7198, 'account_id': 10788, 'date': 940823, 'amount': 45768, 'duration': 12, 'payments': 3814.0, 'status': 'A'}
# {'loan_id': 6686, 'account_id': 8260, 'date': 940825, 'amount': 224604, 'duration': 36, 'payments': 6239.0, 'status': 'A'}
# {'loan_id': 5836, 'account_id': 4259, 'date': 940827, 'amount': 79632, 'duration': 24, 'payments': 3318.0, 'status': 'A'}
# {'loan_id': 7061, 'account_id': 10105, 'date': 940827, 'amount': 121896, 'duration': 24, 'payments': 5079.0, 'status': 'A'}
# {'loan_id': 5595, 'account_id': 3050, 'date': 940902, 'amount': 82896, 'duration': 12, 'payments': 6908.0, 'status': 'A'}
# {'loan_id': 5723, 'account_id': 3674, 'date': 940910, 'amount': 23628, 'duration': 12, 'payments': 1969.0, 'status': 'A'}
# {'loan_id': 6120, 'account_id': 5481, 'date': 940911, 'amount': 209184, 'duration': 48, 'payments': 4358.0, 'status': 'A'}
# {'loan_id': 6895, 'account_id': 9307, 'date': 940919, 'amount': 41904, 'duration': 12, 'payments': 3492.0, 'status': 'A'}
# {'loan_id': 5882, 'account_id': 4427, 'date': 940926, 'amount': 87816, 'duration': 12, 'payments': 7318.0, 'status': 'A'}
# {'loan_id': 5754, 'account_id': 3834, 'date': 940928, 'amount': 23052, 'duration': 12, 'payments': 1921.0, 'status': 'A'}
# {'loan_id': 6594, 'account_id': 7824, 'date': 940928, 'amount': 189696, 'duration': 24, 'payments': 7904.0, 'status': 'B'}
# {'loan_id': 6738, 'account_id': 8566, 'date': 940929, 'amount': 230220, 'duration': 36, 'payments': 6395.0, 'status': 'B'}
# {'loan_id': 6624, 'account_id': 7965, 'date': 940930, 'amount': 71460, 'duration': 12, 'payments': 5955.0, 'status': 'A'}
# {'loan_id': 6216, 'account_id': 5952, 'date': 940930, 'amount': 141240, 'duration': 24, 'payments': 5885.0, 'status': 'A'}
# {'loan_id': 6229, 'account_id': 6040, 'date': 941002, 'amount': 11736, 'duration': 24, 'payments': 489.0, 'status': 'A'}
# {'loan_id': 5887, 'account_id': 4448, 'date': 941003, 'amount': 192744, 'duration': 36, 'payments': 5354.0, 'status': 'A'}
# {'loan_id': 6808, 'account_id': 8982, 'date': 941012, 'amount': 227880, 'duration': 36, 'payments': 6330.0, 'status': 'A'}
# {'loan_id': 6297, 'account_id': 6363, 'date': 941025, 'amount': 17508, 'duration': 12, 'payments': 1459.0, 'status': 'A'}
# {'loan_id': 5161, 'account_id': 1012, 'date': 941028, 'amount': 98184, 'duration': 24, 'payments': 4091.0, 'status': 'A'}
# {'loan_id': 5390, 'account_id': 2167, 'date': 941030, 'amount': 170256, 'duration': 24, 'payments': 7094.0, 'status': 'A'}
# {'loan_id': 6150, 'account_id': 5622, 'date': 941102, 'amount': 83016, 'duration': 12, 'payments': 6918.0, 'status': 'A'}
# {'loan_id': 6223, 'account_id': 5991, 'date': 941103, 'amount': 61056, 'duration': 48, 'payments': 1272.0, 'status': 'A'}
# {'loan_id': 5032, 'account_id': 290, 'date': 941103, 'amount': 123696, 'duration': 48, 'payments': 2577.0, 'status': 'A'}
# {'loan_id': 6253, 'account_id': 6148, 'date': 941104, 'amount': 59760, 'duration': 24, 'payments': 2490.0, 'status': 'A'}
# {'loan_id': 6460, 'account_id': 7133, 'date': 941106, 'amount': 48672, 'duration': 36, 'payments': 1352.0, 'status': 'A'}
# {'loan_id': 6645, 'account_id': 8041, 'date': 941106, 'amount': 140400, 'duration': 36, 'payments': 3900.0, 'status': 'A'}
# {'loan_id': 5176, 'account_id': 1106, 'date': 941112, 'amount': 192552, 'duration': 24, 'payments': 8023.0, 'status': 'B'}
# {'loan_id': 5269, 'account_id': 1527, 'date': 941119, 'amount': 164052, 'duration': 36, 'payments': 4557.0, 'status': 'B'}
# {'loan_id': 5351, 'account_id': 1978, 'date': 941204, 'amount': 205200, 'duration': 36, 'payments': 5700.0, 'status': 'A'}
# {'loan_id': 5861, 'account_id': 4337, 'date': 941208, 'amount': 51408, 'duration': 24, 'payments': 2142.0, 'status': 'A'}
# {'loan_id': 5450, 'account_id': 2345, 'date': 941211, 'amount': 199680, 'duration': 60, 'payments': 3328.0, 'status': 'C'}
# {'loan_id': 7142, 'account_id': 10451, 'date': 941219, 'amount': 482940, 'duration': 60, 'payments': 8049.0, 'status': 'D'}
# {'loan_id': 6306, 'account_id': 6425, 'date': 941220, 'amount': 36684, 'duration': 12, 'payments': 3057.0, 'status': 'A'}
# {'loan_id': 6272, 'account_id': 6226, 'date': 941220, 'amount': 398640, 'duration': 60, 'payments': 6644.0, 'status': 'C'}
# {'loan_id': 5044, 'account_id': 344, 'date': 941221, 'amount': 100980, 'duration': 60, 'payments': 1683.0, 'status': 'C'}
# {'loan_id': 5576, 'account_id': 2962, 'date': 941221, 'amount': 31248, 'duration': 12, 'payments': 2604.0, 'status': 'A'}
# {'loan_id': 7192, 'account_id': 10738, 'date': 941221, 'amount': 115992, 'duration': 36, 'payments': 3222.0, 'status': 'A'}
# {'loan_id': 5739, 'account_id': 3747, 'date': 950102, 'amount': 76380, 'duration': 12, 'payments': 6365.0, 'status': 'A'}
# {'loan_id': 6526, 'account_id': 7523, 'date': 950103, 'amount': 288468, 'duration': 36, 'payments': 8013.0, 'status': 'A'}
# {'loan_id': 5624, 'account_id': 3166, 'date': 950103, 'amount': 177744, 'duration': 48, 'payments': 3703.0, 'status': 'D'}
# {'loan_id': 6244, 'account_id': 6118, 'date': 950108, 'amount': 270648, 'duration': 36, 'payments': 7518.0, 'status': 'B'}
# {'loan_id': 5131, 'account_id': 816, 'date': 950108, 'amount': 48624, 'duration': 24, 'payments': 2026.0, 'status': 'A'}
# {'loan_id': 6960, 'account_id': 9640, 'date': 950111, 'amount': 76416, 'duration': 24, 'payments': 3184.0, 'status': 'A'}
# {'loan_id': 6358, 'account_id': 6715, 'date': 950114, 'amount': 137880, 'duration': 60, 'payments': 2298.0, 'status': 'D'}
# {'loan_id': 5418, 'account_id': 2245, 'date': 950116, 'amount': 347952, 'duration': 48, 'payments': 7249.0, 'status': 'C'}
# {'loan_id': 6598, 'account_id': 7857, 'date': 950118, 'amount': 68112, 'duration': 12, 'payments': 5676.0, 'status': 'A'}
# {'loan_id': 5464, 'account_id': 2419, 'date': 950130, 'amount': 95808, 'duration': 12, 'payments': 7984.0, 'status': 'A'}
# {'loan_id': 6591, 'account_id': 7819, 'date': 950202, 'amount': 20832, 'duration': 48, 'payments': 434.0, 'status': 'C'}
# {'loan_id': 5724, 'account_id': 3678, 'date': 950205, 'amount': 316140, 'duration': 60, 'payments': 5269.0, 'status': 'D'}
# {'loan_id': 6315, 'account_id': 6472, 'date': 950206, 'amount': 43164, 'duration': 12, 'payments': 3597.0, 'status': 'A'}
# {'loan_id': 5876, 'account_id': 4413, 'date': 950208, 'amount': 221280, 'duration': 48, 'payments': 4610.0, 'status': 'C'}
# {'loan_id': 6986, 'account_id': 9750, 'date': 950211, 'amount': 151728, 'duration': 48, 'payments': 3161.0, 'status': 'D'}
# {'loan_id': 6294, 'account_id': 6353, 'date': 950212, 'amount': 79920, 'duration': 60, 'payments': 1332.0, 'status': 'C'}
# {'loan_id': 5132, 'account_id': 817, 'date': 950217, 'amount': 538500, 'duration': 60, 'payments': 8975.0, 'status': 'C'}
# {'loan_id': 5877, 'account_id': 4414, 'date': 950223, 'amount': 97224, 'duration': 24, 'payments': 4051.0, 'status': 'A'}
# {'loan_id': 6227, 'account_id': 6030, 'date': 950304, 'amount': 28248, 'duration': 24, 'payments': 1177.0, 'status': 'A'}
# {'loan_id': 7241, 'account_id': 11021, 'date': 950304, 'amount': 168984, 'duration': 24, 'payments': 7041.0, 'status': 'B'}
# {'loan_id': 6737, 'account_id': 8564, 'date': 950311, 'amount': 76680, 'duration': 24, 'payments': 3195.0, 'status': 'A'}
# {'loan_id': 7004, 'account_id': 9869, 'date': 950315, 'amount': 331560, 'duration': 60, 'payments': 5526.0, 'status': 'C'}
# {'loan_id': 6169, 'account_id': 5700, 'date': 950316, 'amount': 103680, 'duration': 60, 'payments': 1728.0, 'status': 'D'}
# {'loan_id': 5208, 'account_id': 1247, 'date': 950316, 'amount': 99696, 'duration': 48, 'payments': 2077.0, 'status': 'D'}
# {'loan_id': 6694, 'account_id': 8316, 'date': 950319, 'amount': 134784, 'duration': 24, 'payments': 5616.0, 'status': 'A'}
# {'loan_id': 5599, 'account_id': 3064, 'date': 950321, 'amount': 15420, 'duration': 12, 'payments': 1285.0, 'status': 'A'}
# {'loan_id': 6546, 'account_id': 7607, 'date': 950327, 'amount': 31728, 'duration': 24, 'payments': 1322.0, 'status': 'A'}
# {'loan_id': 5414, 'account_id': 2228, 'date': 950329, 'amount': 185952, 'duration': 48, 'payments': 3874.0, 'status': 'C'}
# {'loan_id': 5453, 'account_id': 2361, 'date': 950401, 'amount': 156672, 'duration': 36, 'payments': 4352.0, 'status': 'A'}
# {'loan_id': 5740, 'account_id': 3752, 'date': 950402, 'amount': 18564, 'duration': 12, 'payments': 1547.0, 'status': 'A'}
# {'loan_id': 5804, 'account_id': 4079, 'date': 950405, 'amount': 158976, 'duration': 48, 'payments': 3312.0, 'status': 'C'}
# {'loan_id': 6745, 'account_id': 8625, 'date': 950410, 'amount': 47304, 'duration': 24, 'payments': 1971.0, 'status': 'A'}
# {'loan_id': 6950, 'account_id': 9591, 'date': 950411, 'amount': 104712, 'duration': 24, 'payments': 4363.0, 'status': 'A'}
# {'loan_id': 6996, 'account_id': 9828, 'date': 950413, 'amount': 126600, 'duration': 24, 'payments': 5275.0, 'status': 'A'}
# {'loan_id': 5352, 'account_id': 1993, 'date': 950415, 'amount': 68400, 'duration': 12, 'payments': 5700.0, 'status': 'B'}
# {'loan_id': 6151, 'account_id': 5628, 'date': 950425, 'amount': 225420, 'duration': 60, 'payments': 3757.0, 'status': 'C'}
# {'loan_id': 5310, 'account_id': 1762, 'date': 950428, 'amount': 248148, 'duration': 36, 'payments': 6893.0, 'status': 'A'}
# {'loan_id': 5045, 'account_id': 347, 'date': 950501, 'amount': 187224, 'duration': 24, 'payments': 7801.0, 'status': 'B'}
# {'loan_id': 6929, 'account_id': 9472, 'date': 950508, 'amount': 36396, 'duration': 12, 'payments': 3033.0, 'status': 'A'}
# {'loan_id': 5151, 'account_id': 960, 'date': 950524, 'amount': 189060, 'duration': 60, 'payments': 3151.0, 'status': 'C'}
# {'loan_id': 5212, 'account_id': 1256, 'date': 950529, 'amount': 71064, 'duration': 36, 'payments': 1974.0, 'status': 'A'}
# {'loan_id': 5138, 'account_id': 854, 'date': 950530, 'amount': 87216, 'duration': 48, 'payments': 1817.0, 'status': 'C'}
# {'loan_id': 5713, 'account_id': 3629, 'date': 950530, 'amount': 158760, 'duration': 60, 'payments': 2646.0, 'status': 'C'}
# {'loan_id': 6704, 'account_id': 8377, 'date': 950601, 'amount': 417060, 'duration': 60, 'payments': 6951.0, 'status': 'C'}
# {'loan_id': 6474, 'account_id': 7190, 'date': 950606, 'amount': 63360, 'duration': 60, 'payments': 1056.0, 'status': 'C'}
# {'loan_id': 6676, 'account_id': 8159, 'date': 950613, 'amount': 29784, 'duration': 24, 'payments': 1241.0, 'status': 'A'}
# {'loan_id': 6965, 'account_id': 9656, 'date': 950613, 'amount': 139536, 'duration': 24, 'payments': 5814.0, 'status': 'A'}
# {'loan_id': 6725, 'account_id': 8489, 'date': 950623, 'amount': 265320, 'duration': 36, 'payments': 7370.0, 'status': 'A'}
# {'loan_id': 7166, 'account_id': 10630, 'date': 950624, 'amount': 198240, 'duration': 24, 'payments': 8260.0, 'status': 'A'}
# {'loan_id': 7138, 'account_id': 10440, 'date': 950703, 'amount': 60000, 'duration': 60, 'payments': 1000.0, 'status': 'C'}
# {'loan_id': 5970, 'account_id': 4774, 'date': 950709, 'amount': 465072, 'duration': 48, 'payments': 9689.0, 'status': 'C'}
# {'loan_id': 6157, 'account_id': 5650, 'date': 950710, 'amount': 98592, 'duration': 24, 'payments': 4108.0, 'status': 'A'}
# {'loan_id': 6153, 'account_id': 5632, 'date': 950725, 'amount': 285600, 'duration': 60, 'payments': 4760.0, 'status': 'C'}
# {'loan_id': 5693, 'account_id': 3489, 'date': 950801, 'amount': 44088, 'duration': 24, 'payments': 1837.0, 'status': 'A'}
# {'loan_id': 5922, 'account_id': 4580, 'date': 950805, 'amount': 20220, 'duration': 12, 'payments': 1685.0, 'status': 'A'}
# {'loan_id': 5959, 'account_id': 4727, 'date': 950811, 'amount': 107640, 'duration': 24, 'payments': 4485.0, 'status': 'A'}
# {'loan_id': 5980, 'account_id': 4825, 'date': 950818, 'amount': 21396, 'duration': 12, 'payments': 1783.0, 'status': 'A'}
# {'loan_id': 6764, 'account_id': 8776, 'date': 950826, 'amount': 33984, 'duration': 48, 'payments': 708.0, 'status': 'C'}
# {'loan_id': 5237, 'account_id': 1375, 'date': 950829, 'amount': 45336, 'duration': 24, 'payments': 1889.0, 'status': 'A'}
# {'loan_id': 6726, 'account_id': 8492, 'date': 950903, 'amount': 85860, 'duration': 60, 'payments': 1431.0, 'status': 'C'}
# {'loan_id': 6933, 'account_id': 9493, 'date': 950909, 'amount': 188688, 'duration': 48, 'payments': 3931.0, 'status': 'C'}
# {'loan_id': 5145, 'account_id': 915, 'date': 950916, 'amount': 309552, 'duration': 48, 'payments': 6449.0, 'status': 'C'}
# {'loan_id': 7008, 'account_id': 9897, 'date': 950922, 'amount': 36168, 'duration': 12, 'payments': 3014.0, 'status': 'A'}
# {'loan_id': 7227, 'account_id': 10942, 'date': 951002, 'amount': 314520, 'duration': 60, 'payments': 5242.0, 'status': 'C'}
# {'loan_id': 6600, 'account_id': 7861, 'date': 951008, 'amount': 21852, 'duration': 36, 'payments': 607.0, 'status': 'A'}
# {'loan_id': 6712, 'account_id': 8405, 'date': 951014, 'amount': 266220, 'duration': 60, 'payments': 4437.0, 'status': 'C'}
# {'loan_id': 7057, 'account_id': 10093, 'date': 951020, 'amount': 231696, 'duration': 36, 'payments': 6436.0, 'status': 'A'}
# {'loan_id': 7176, 'account_id': 10663, 'date': 951028, 'amount': 260028, 'duration': 36, 'payments': 7223.0, 'status': 'A'}
# {'loan_id': 7304, 'account_id': 11349, 'date': 951029, 'amount': 419880, 'duration': 60, 'payments': 6998.0, 'status': 'C'}
# {'loan_id': 6362, 'account_id': 6738, 'date': 951031, 'amount': 37908, 'duration': 12, 'payments': 3159.0, 'status': 'A'}
# {'loan_id': 5880, 'account_id': 4423, 'date': 951031, 'amount': 73836, 'duration': 36, 'payments': 2051.0, 'status': 'A'}
# {'loan_id': 6535, 'account_id': 7546, 'date': 951102, 'amount': 41952, 'duration': 12, 'payments': 3496.0, 'status': 'A'}
# {'loan_id': 5449, 'account_id': 2343, 'date': 951104, 'amount': 99336, 'duration': 24, 'payments': 4139.0, 'status': 'A'}
# {'loan_id': 6342, 'account_id': 6609, 'date': 951112, 'amount': 60156, 'duration': 36, 'payments': 1671.0, 'status': 'B'}
# {'loan_id': 5409, 'account_id': 2218, 'date': 951118, 'amount': 182040, 'duration': 60, 'payments': 3034.0, 'status': 'C'}
# {'loan_id': 6955, 'account_id': 9627, 'date': 951122, 'amount': 244368, 'duration': 48, 'payments': 5091.0, 'status': 'C'}
# {'loan_id': 6985, 'account_id': 9731, 'date': 951122, 'amount': 113796, 'duration': 36, 'payments': 3161.0, 'status': 'A'}
# {'loan_id': 5125, 'account_id': 789, 'date': 951123, 'amount': 73056, 'duration': 48, 'payments': 1522.0, 'status': 'C'}
# {'loan_id': 5805, 'account_id': 4081, 'date': 951128, 'amount': 137904, 'duration': 24, 'payments': 5746.0, 'status': 'B'}
# {'loan_id': 6185, 'account_id': 5774, 'date': 951128, 'amount': 31176, 'duration': 24, 'payments': 1299.0, 'status': 'A'}
# {'loan_id': 7243, 'account_id': 11042, 'date': 951204, 'amount': 217152, 'duration': 36, 'payments': 6032.0, 'status': 'A'}
# {'loan_id': 6403, 'account_id': 6924, 'date': 951205, 'amount': 194880, 'duration': 48, 'payments': 4060.0, 'status': 'C'}
# {'loan_id': 6578, 'account_id': 7765, 'date': 951211, 'amount': 27984, 'duration': 12, 'payments': 2332.0, 'status': 'A'}
# {'loan_id': 5413, 'account_id': 2227, 'date': 951212, 'amount': 92976, 'duration': 24, 'payments': 3874.0, 'status': 'A'}
# {'loan_id': 6949, 'account_id': 9583, 'date': 951212, 'amount': 104712, 'duration': 24, 'payments': 4363.0, 'status': 'A'}
# {'loan_id': 6545, 'account_id': 7606, 'date': 951212, 'amount': 191880, 'duration': 60, 'payments': 3198.0, 'status': 'C'}
# {'loan_id': 6178, 'account_id': 5742, 'date': 951216, 'amount': 232560, 'duration': 48, 'payments': 4845.0, 'status': 'C'}
# {'loan_id': 5160, 'account_id': 1011, 'date': 951218, 'amount': 204000, 'duration': 60, 'payments': 3400.0, 'status': 'C'}
# {'loan_id': 6785, 'account_id': 8899, 'date': 951225, 'amount': 125340, 'duration': 60, 'payments': 2089.0, 'status': 'C'}
# {'loan_id': 6540, 'account_id': 7562, 'date': 951231, 'amount': 309600, 'duration': 48, 'payments': 6450.0, 'status': 'C'}
# {'loan_id': 6589, 'account_id': 7815, 'date': 960101, 'amount': 189696, 'duration': 24, 'payments': 7904.0, 'status': 'A'}
# {'loan_id': 5900, 'account_id': 4503, 'date': 960101, 'amount': 135360, 'duration': 48, 'payments': 2820.0, 'status': 'C'}
# {'loan_id': 5999, 'account_id': 4907, 'date': 960103, 'amount': 98832, 'duration': 48, 'payments': 2059.0, 'status': 'C'}
# {'loan_id': 6043, 'account_id': 5126, 'date': 960111, 'amount': 20352, 'duration': 48, 'payments': 424.0, 'status': 'C'}
# {'loan_id': 5482, 'account_id': 2496, 'date': 960112, 'amount': 165120, 'duration': 60, 'payments': 2752.0, 'status': 'C'}
# {'loan_id': 7263, 'account_id': 11138, 'date': 960119, 'amount': 89880, 'duration': 24, 'payments': 3745.0, 'status': 'A'}
# {'loan_id': 6013, 'account_id': 4995, 'date': 960203, 'amount': 128988, 'duration': 36, 'payments': 3583.0, 'status': 'D'}
# {'loan_id': 5750, 'account_id': 3804, 'date': 960208, 'amount': 63252, 'duration': 12, 'payments': 5271.0, 'status': 'A'}
# {'loan_id': 6027, 'account_id': 5066, 'date': 960210, 'amount': 61656, 'duration': 24, 'payments': 2569.0, 'status': 'B'}
# {'loan_id': 6303, 'account_id': 6400, 'date': 960212, 'amount': 72408, 'duration': 24, 'payments': 3017.0, 'status': 'B'}
# {'loan_id': 7213, 'account_id': 10884, 'date': 960213, 'amount': 113544, 'duration': 36, 'payments': 3154.0, 'status': 'C'}
# {'loan_id': 6659, 'account_id': 8092, 'date': 960220, 'amount': 56100, 'duration': 60, 'payments': 935.0, 'status': 'C'}
# {'loan_id': 6175, 'account_id': 5735, 'date': 960221, 'amount': 290700, 'duration': 60, 'payments': 4845.0, 'status': 'D'}
# {'loan_id': 5610, 'account_id': 3112, 'date': 960224, 'amount': 123216, 'duration': 48, 'payments': 2567.0, 'status': 'C'}
# {'loan_id': 5563, 'account_id': 2912, 'date': 960229, 'amount': 380160, 'duration': 60, 'payments': 6336.0, 'status': 'C'}
# {'loan_id': 5989, 'account_id': 4852, 'date': 960304, 'amount': 213300, 'duration': 36, 'payments': 5925.0, 'status': 'C'}
# {'loan_id': 6698, 'account_id': 8327, 'date': 960310, 'amount': 247728, 'duration': 48, 'payments': 5161.0, 'status': 'C'}
# {'loan_id': 5312, 'account_id': 1772, 'date': 960313, 'amount': 202788, 'duration': 36, 'payments': 5633.0, 'status': 'C'}
# {'loan_id': 7189, 'account_id': 10728, 'date': 960321, 'amount': 154656, 'duration': 48, 'payments': 3222.0, 'status': 'C'}
# {'loan_id': 6816, 'account_id': 9017, 'date': 960326, 'amount': 100224, 'duration': 48, 'payments': 2088.0, 'status': 'D'}
# {'loan_id': 6137, 'account_id': 5574, 'date': 960410, 'amount': 44628, 'duration': 12, 'payments': 3719.0, 'status': 'A'}
# {'loan_id': 5128, 'account_id': 808, 'date': 960411, 'amount': 215616, 'duration': 48, 'payments': 4492.0, 'status': 'D'}
# {'loan_id': 5470, 'account_id': 2456, 'date': 960415, 'amount': 200976, 'duration': 48, 'payments': 4187.0, 'status': 'C'}
# {'loan_id': 5593, 'account_id': 3037, 'date': 960418, 'amount': 277884, 'duration': 36, 'payments': 7719.0, 'status': 'D'}
# {'loan_id': 5350, 'account_id': 1967, 'date': 960421, 'amount': 249312, 'duration': 48, 'payments': 5194.0, 'status': 'C'}
# {'loan_id': 6063, 'account_id': 5213, 'date': 960425, 'amount': 320976, 'duration': 48, 'payments': 6687.0, 'status': 'D'}
# {'loan_id': 6501, 'account_id': 7418, 'date': 960429, 'amount': 30276, 'duration': 12, 'payments': 2523.0, 'status': 'B'}
# {'loan_id': 5452, 'account_id': 2352, 'date': 960429, 'amount': 49440, 'duration': 60, 'payments': 824.0, 'status': 'C'}
# {'loan_id': 4961, 'account_id': 19, 'date': 960429, 'amount': 30276, 'duration': 12, 'payments': 2523.0, 'status': 'B'}
# {'loan_id': 4973, 'account_id': 67, 'date': 960502, 'amount': 165960, 'duration': 24, 'payments': 6915.0, 'status': 'A'}
# {'loan_id': 6190, 'account_id': 5794, 'date': 960506, 'amount': 123600, 'duration': 60, 'payments': 2060.0, 'status': 'C'}
# {'loan_id': 6715, 'account_id': 8411, 'date': 960506, 'amount': 220620, 'duration': 60, 'payments': 3677.0, 'status': 'C'}
# {'loan_id': 5892, 'account_id': 4462, 'date': 960514, 'amount': 66480, 'duration': 24, 'payments': 2770.0, 'status': 'B'}
# {'loan_id': 6550, 'account_id': 7614, 'date': 960518, 'amount': 320592, 'duration': 48, 'payments': 6679.0, 'status': 'C'}
# {'loan_id': 5706, 'account_id': 3608, 'date': 960524, 'amount': 161496, 'duration': 36, 'payments': 4486.0, 'status': 'C'}
# {'loan_id': 5148, 'account_id': 940, 'date': 960529, 'amount': 284280, 'duration': 60, 'payments': 4738.0, 'status': 'C'}
# {'loan_id': 6734, 'account_id': 8547, 'date': 960530, 'amount': 173016, 'duration': 36, 'payments': 4806.0, 'status': 'C'}
# {'loan_id': 6109, 'account_id': 5422, 'date': 960603, 'amount': 368880, 'duration': 60, 'payments': 6148.0, 'status': 'C'}
# {'loan_id': 6961, 'account_id': 9645, 'date': 960606, 'amount': 176148, 'duration': 36, 'payments': 4893.0, 'status': 'C'}
# {'loan_id': 6810, 'account_id': 9006, 'date': 960608, 'amount': 186384, 'duration': 48, 'payments': 3883.0, 'status': 'C'}
# {'loan_id': 5494, 'account_id': 2572, 'date': 960613, 'amount': 360000, 'duration': 48, 'payments': 7500.0, 'status': 'C'}
# {'loan_id': 5311, 'account_id': 1766, 'date': 960615, 'amount': 30060, 'duration': 60, 'payments': 501.0, 'status': 'C'}
# {'loan_id': 5445, 'account_id': 2322, 'date': 960629, 'amount': 46320, 'duration': 24, 'payments': 1930.0, 'status': 'A'}
# {'loan_id': 5301, 'account_id': 1698, 'date': 960706, 'amount': 141948, 'duration': 36, 'payments': 3943.0, 'status': 'C'}
# {'loan_id': 7034, 'account_id': 10001, 'date': 960711, 'amount': 19044, 'duration': 36, 'payments': 529.0, 'status': 'C'}
# {'loan_id': 6751, 'account_id': 8680, 'date': 960714, 'amount': 85716, 'duration': 36, 'payments': 2381.0, 'status': 'C'}
# {'loan_id': 6667, 'account_id': 8127, 'date': 960715, 'amount': 155880, 'duration': 24, 'payments': 6495.0, 'status': 'A'}
# {'loan_id': 6130, 'account_id': 5541, 'date': 960718, 'amount': 32640, 'duration': 48, 'payments': 680.0, 'status': 'C'}
# {'loan_id': 5429, 'account_id': 2268, 'date': 960718, 'amount': 20196, 'duration': 36, 'payments': 561.0, 'status': 'C'}
# {'loan_id': 5725, 'account_id': 3679, 'date': 960723, 'amount': 444864, 'duration': 48, 'payments': 9268.0, 'status': 'C'}
# {'loan_id': 6019, 'account_id': 5033, 'date': 960725, 'amount': 11400, 'duration': 12, 'payments': 950.0, 'status': 'A'}
# {'loan_id': 6421, 'account_id': 6985, 'date': 960725, 'amount': 96768, 'duration': 36, 'payments': 2688.0, 'status': 'C'}
# {'loan_id': 6992, 'account_id': 9790, 'date': 960727, 'amount': 133968, 'duration': 48, 'payments': 2791.0, 'status': 'C'}
# {'loan_id': 5136, 'account_id': 846, 'date': 960728, 'amount': 187104, 'duration': 24, 'payments': 7796.0, 'status': 'A'}
# {'loan_id': 5337, 'account_id': 1886, 'date': 960731, 'amount': 162468, 'duration': 36, 'payments': 4513.0, 'status': 'C'}
# {'loan_id': 5495, 'account_id': 2580, 'date': 960802, 'amount': 89340, 'duration': 60, 'payments': 1489.0, 'status': 'C'}
# {'loan_id': 7013, 'account_id': 9928, 'date': 960802, 'amount': 89340, 'duration': 60, 'payments': 1489.0, 'status': 'C'}
# {'loan_id': 6012, 'account_id': 4994, 'date': 960803, 'amount': 258444, 'duration': 36, 'payments': 7179.0, 'status': 'C'}
# {'loan_id': 6471, 'account_id': 7184, 'date': 960804, 'amount': 155640, 'duration': 24, 'payments': 6485.0, 'status': 'A'}
# {'loan_id': 6296, 'account_id': 6358, 'date': 960806, 'amount': 270384, 'duration': 48, 'payments': 5633.0, 'status': 'C'}
# {'loan_id': 7305, 'account_id': 11359, 'date': 960806, 'amount': 54024, 'duration': 12, 'payments': 4502.0, 'status': 'A'}
# {'loan_id': 6144, 'account_id': 5593, 'date': 960809, 'amount': 44376, 'duration': 12, 'payments': 3698.0, 'status': 'A'}
# {'loan_id': 6283, 'account_id': 6289, 'date': 960811, 'amount': 85632, 'duration': 48, 'payments': 1784.0, 'status': 'C'}
# {'loan_id': 7246, 'account_id': 11054, 'date': 960820, 'amount': 148920, 'duration': 60, 'payments': 2482.0, 'status': 'C'}
# {'loan_id': 5088, 'account_id': 544, 'date': 960822, 'amount': 91152, 'duration': 24, 'payments': 3798.0, 'status': 'A'}
# {'loan_id': 5988, 'account_id': 4851, 'date': 960822, 'amount': 141648, 'duration': 24, 'payments': 5902.0, 'status': 'A'}
# {'loan_id': 5282, 'account_id': 1583, 'date': 960824, 'amount': 388512, 'duration': 48, 'payments': 8094.0, 'status': 'D'}
# {'loan_id': 5938, 'account_id': 4650, 'date': 960825, 'amount': 402000, 'duration': 60, 'payments': 6700.0, 'status': 'C'}
# {'loan_id': 5606, 'account_id': 3084, 'date': 960828, 'amount': 253512, 'duration': 36, 'payments': 7042.0, 'status': 'D'}
# {'loan_id': 5385, 'account_id': 2143, 'date': 960909, 'amount': 71460, 'duration': 36, 'payments': 1985.0, 'status': 'C'}
# {'loan_id': 6865, 'account_id': 9199, 'date': 960911, 'amount': 29448, 'duration': 12, 'payments': 2454.0, 'status': 'B'}
# {'loan_id': 5586, 'account_id': 2994, 'date': 960914, 'amount': 48744, 'duration': 36, 'payments': 1354.0, 'status': 'C'}
# {'loan_id': 6302, 'account_id': 6397, 'date': 960916, 'amount': 181020, 'duration': 60, 'payments': 3017.0, 'status': 'C'}
# {'loan_id': 7194, 'account_id': 10762, 'date': 960917, 'amount': 68832, 'duration': 36, 'payments': 1912.0, 'status': 'C'}
# {'loan_id': 6461, 'account_id': 7136, 'date': 960919, 'amount': 74124, 'duration': 36, 'payments': 2059.0, 'status': 'C'}
# {'loan_id': 6732, 'account_id': 8533, 'date': 960919, 'amount': 174048, 'duration': 48, 'payments': 3626.0, 'status': 'C'}
# {'loan_id': 6613, 'account_id': 7926, 'date': 960922, 'amount': 84120, 'duration': 24, 'payments': 3505.0, 'status': 'A'}
# {'loan_id': 7036, 'account_id': 10019, 'date': 960925, 'amount': 194940, 'duration': 36, 'payments': 5415.0, 'status': 'C'}
# {'loan_id': 5897, 'account_id': 4476, 'date': 960925, 'amount': 15192, 'duration': 24, 'payments': 633.0, 'status': 'A'}
# {'loan_id': 6995, 'account_id': 9814, 'date': 960926, 'amount': 96168, 'duration': 12, 'payments': 8014.0, 'status': 'A'}
# {'loan_id': 5415, 'account_id': 2236, 'date': 960926, 'amount': 139464, 'duration': 36, 'payments': 3874.0, 'status': 'D'}
# {'loan_id': 7136, 'account_id': 10436, 'date': 960928, 'amount': 54396, 'duration': 36, 'payments': 1511.0, 'status': 'C'}
# {'loan_id': 7271, 'account_id': 11186, 'date': 961002, 'amount': 392460, 'duration': 60, 'payments': 6541.0, 'status': 'C'}
# {'loan_id': 5375, 'account_id': 2106, 'date': 961003, 'amount': 101520, 'duration': 12, 'payments': 8460.0, 'status': 'A'}
# {'loan_id': 5635, 'account_id': 3230, 'date': 961004, 'amount': 77184, 'duration': 36, 'payments': 2144.0, 'status': 'C'}
# {'loan_id': 6817, 'account_id': 9024, 'date': 961004, 'amount': 70656, 'duration': 48, 'payments': 1472.0, 'status': 'C'}
# {'loan_id': 5923, 'account_id': 4585, 'date': 961010, 'amount': 64656, 'duration': 48, 'payments': 1347.0, 'status': 'C'}
# {'loan_id': 5329, 'account_id': 1862, 'date': 961016, 'amount': 396120, 'duration': 60, 'payments': 6602.0, 'status': 'C'}
# {'loan_id': 6644, 'account_id': 8039, 'date': 961020, 'amount': 93600, 'duration': 24, 'payments': 3900.0, 'status': 'A'}
# {'loan_id': 6354, 'account_id': 6688, 'date': 961023, 'amount': 22968, 'duration': 36, 'payments': 638.0, 'status': 'C'}
# {'loan_id': 5082, 'account_id': 501, 'date': 961024, 'amount': 262980, 'duration': 60, 'payments': 4383.0, 'status': 'C'}
# {'loan_id': 6585, 'account_id': 7795, 'date': 961029, 'amount': 372120, 'duration': 60, 'payments': 6202.0, 'status': 'C'}
# {'loan_id': 6921, 'account_id': 9422, 'date': 961029, 'amount': 86184, 'duration': 12, 'payments': 7182.0, 'status': 'A'}
# {'loan_id': 5366, 'account_id': 2062, 'date': 961029, 'amount': 86184, 'duration': 12, 'payments': 7182.0, 'status': 'A'}
# {'loan_id': 5886, 'account_id': 4447, 'date': 961031, 'amount': 192744, 'duration': 36, 'payments': 5354.0, 'status': 'C'}
# {'loan_id': 5741, 'account_id': 3754, 'date': 961103, 'amount': 68544, 'duration': 24, 'payments': 2856.0, 'status': 'A'}
# {'loan_id': 4996, 'account_id': 132, 'date': 961106, 'amount': 88440, 'duration': 12, 'payments': 7370.0, 'status': 'A'}
# {'loan_id': 6015, 'account_id': 5001, 'date': 961109, 'amount': 110112, 'duration': 24, 'payments': 4588.0, 'status': 'A'}
# {'loan_id': 6309, 'account_id': 6434, 'date': 961111, 'amount': 110136, 'duration': 24, 'payments': 4589.0, 'status': 'A'}
# {'loan_id': 6073, 'account_id': 5263, 'date': 961112, 'amount': 276300, 'duration': 60, 'payments': 4605.0, 'status': 'C'}
# {'loan_id': 6006, 'account_id': 4948, 'date': 961115, 'amount': 359760, 'duration': 60, 'payments': 5996.0, 'status': 'C'}
# {'loan_id': 5611, 'account_id': 3115, 'date': 961115, 'amount': 321180, 'duration': 60, 'payments': 5353.0, 'status': 'C'}
# {'loan_id': 6944, 'account_id': 9548, 'date': 961115, 'amount': 46176, 'duration': 48, 'payments': 962.0, 'status': 'C'}
# {'loan_id': 7101, 'account_id': 10297, 'date': 961118, 'amount': 421008, 'duration': 48, 'payments': 8771.0, 'status': 'C'}
# {'loan_id': 6599, 'account_id': 7859, 'date': 961119, 'amount': 72120, 'duration': 12, 'payments': 6010.0, 'status': 'A'}
# {'loan_id': 6940, 'account_id': 9510, 'date': 961122, 'amount': 228276, 'duration': 36, 'payments': 6341.0, 'status': 'C'}
# {'loan_id': 5209, 'account_id': 1250, 'date': 961125, 'amount': 182640, 'duration': 48, 'payments': 3805.0, 'status': 'C'}
# {'loan_id': 5388, 'account_id': 2153, 'date': 961128, 'amount': 61560, 'duration': 12, 'payments': 5130.0, 'status': 'A'}
# {'loan_id': 6011, 'account_id': 4981, 'date': 961128, 'amount': 179328, 'duration': 48, 'payments': 3736.0, 'status': 'C'}
# {'loan_id': 5591, 'account_id': 3021, 'date': 961204, 'amount': 155616, 'duration': 48, 'payments': 3242.0, 'status': 'C'}
# {'loan_id': 7154, 'account_id': 10520, 'date': 961205, 'amount': 417600, 'duration': 60, 'payments': 6960.0, 'status': 'C'}
# {'loan_id': 7130, 'account_id': 10411, 'date': 961211, 'amount': 123408, 'duration': 24, 'payments': 5142.0, 'status': 'A'}
# {'loan_id': 6818, 'account_id': 9030, 'date': 961212, 'amount': 155616, 'duration': 48, 'payments': 3242.0, 'status': 'C'}
# {'loan_id': 5625, 'account_id': 3189, 'date': 961215, 'amount': 222180, 'duration': 60, 'payments': 3703.0, 'status': 'D'}
# {'loan_id': 6805, 'account_id': 8972, 'date': 961221, 'amount': 45024, 'duration': 48, 'payments': 938.0, 'status': 'C'}
# {'loan_id': 7233, 'account_id': 10963, 'date': 961225, 'amount': 115812, 'duration': 36, 'payments': 3217.0, 'status': 'C'}
# {'loan_id': 7308, 'account_id': 11362, 'date': 961227, 'amount': 129408, 'duration': 24, 'payments': 5392.0, 'status': 'A'}
# {'loan_id': 5895, 'account_id': 4473, 'date': 970103, 'amount': 93960, 'duration': 60, 'payments': 1566.0, 'status': 'C'}
# {'loan_id': 7122, 'account_id': 10365, 'date': 970104, 'amount': 260640, 'duration': 36, 'payments': 7240.0, 'status': 'D'}
# {'loan_id': 6173, 'account_id': 5724, 'date': 970108, 'amount': 232560, 'duration': 48, 'payments': 4845.0, 'status': 'C'}
# {'loan_id': 6142, 'account_id': 5591, 'date': 970121, 'amount': 221880, 'duration': 60, 'payments': 3698.0, 'status': 'C'}
# {'loan_id': 5358, 'account_id': 2018, 'date': 970121, 'amount': 38520, 'duration': 12, 'payments': 3210.0, 'status': 'A'}
# {'loan_id': 6095, 'account_id': 5358, 'date': 970124, 'amount': 68340, 'duration': 60, 'payments': 1139.0, 'status': 'C'}
# {'loan_id': 6878, 'account_id': 9242, 'date': 970124, 'amount': 23184, 'duration': 12, 'payments': 1932.0, 'status': 'A'}
# {'loan_id': 6554, 'account_id': 7637, 'date': 970129, 'amount': 390096, 'duration': 48, 'payments': 8127.0, 'status': 'C'}
# {'loan_id': 6793, 'account_id': 8931, 'date': 970130, 'amount': 186300, 'duration': 60, 'payments': 3105.0, 'status': 'C'}
# {'loan_id': 7286, 'account_id': 11271, 'date': 970131, 'amount': 67320, 'duration': 36, 'payments': 1870.0, 'status': 'C'}
# {'loan_id': 6076, 'account_id': 5269, 'date': 970202, 'amount': 117420, 'duration': 60, 'payments': 1957.0, 'status': 'C'}
# {'loan_id': 5134, 'account_id': 825, 'date': 970202, 'amount': 53076, 'duration': 12, 'payments': 4423.0, 'status': 'A'}
# {'loan_id': 5419, 'account_id': 2246, 'date': 970205, 'amount': 415800, 'duration': 60, 'payments': 6930.0, 'status': 'C'}
# {'loan_id': 6255, 'account_id': 6158, 'date': 970208, 'amount': 247920, 'duration': 48, 'payments': 5165.0, 'status': 'D'}
# {'loan_id': 5656, 'account_id': 3353, 'date': 970209, 'amount': 146064, 'duration': 24, 'payments': 6086.0, 'status': 'C'}
# {'loan_id': 6934, 'account_id': 9494, 'date': 970209, 'amount': 116832, 'duration': 12, 'payments': 9736.0, 'status': 'A'}
# {'loan_id': 6028, 'account_id': 5072, 'date': 970209, 'amount': 317520, 'duration': 60, 'payments': 5292.0, 'status': 'C'}
# {'loan_id': 6490, 'account_id': 7262, 'date': 970210, 'amount': 73260, 'duration': 60, 'payments': 1221.0, 'status': 'C'}
# {'loan_id': 6415, 'account_id': 6950, 'date': 970212, 'amount': 475680, 'duration': 48, 'payments': 9910.0, 'status': 'C'}
# {'loan_id': 7087, 'account_id': 10215, 'date': 970220, 'amount': 44304, 'duration': 24, 'payments': 1846.0, 'status': 'C'}
# {'loan_id': 5420, 'account_id': 2247, 'date': 970224, 'amount': 72504, 'duration': 24, 'payments': 3021.0, 'status': 'C'}
# {'loan_id': 5977, 'account_id': 4803, 'date': 970225, 'amount': 59136, 'duration': 48, 'payments': 1232.0, 'status': 'C'}
# {'loan_id': 6824, 'account_id': 9052, 'date': 970226, 'amount': 71976, 'duration': 24, 'payments': 2999.0, 'status': 'D'}
# {'loan_id': 5207, 'account_id': 1244, 'date': 970228, 'amount': 35904, 'duration': 48, 'payments': 748.0, 'status': 'C'}
# {'loan_id': 7115, 'account_id': 10351, 'date': 970304, 'amount': 88704, 'duration': 48, 'payments': 1848.0, 'status': 'C'}
# {'loan_id': 7250, 'account_id': 11069, 'date': 970304, 'amount': 119136, 'duration': 48, 'payments': 2482.0, 'status': 'C'}
# {'loan_id': 6010, 'account_id': 4969, 'date': 970306, 'amount': 150180, 'duration': 60, 'payments': 2503.0, 'status': 'C'}
# {'loan_id': 6088, 'account_id': 5317, 'date': 970307, 'amount': 90180, 'duration': 36, 'payments': 2505.0, 'status': 'C'}
# {'loan_id': 5682, 'account_id': 3455, 'date': 970307, 'amount': 67464, 'duration': 12, 'payments': 5622.0, 'status': 'A'}
# {'loan_id': 7201, 'account_id': 10807, 'date': 970307, 'amount': 67464, 'duration': 12, 'payments': 5622.0, 'status': 'A'}
# {'loan_id': 6938, 'account_id': 9504, 'date': 970310, 'amount': 341280, 'duration': 60, 'payments': 5688.0, 'status': 'C'}
# {'loan_id': 6875, 'account_id': 9235, 'date': 970313, 'amount': 83280, 'duration': 48, 'payments': 1735.0, 'status': 'C'}
# {'loan_id': 5953, 'account_id': 4715, 'date': 970314, 'amount': 97176, 'duration': 24, 'payments': 4049.0, 'status': 'C'}
# {'loan_id': 5942, 'account_id': 4681, 'date': 970315, 'amount': 162624, 'duration': 48, 'payments': 3388.0, 'status': 'C'}
# {'loan_id': 5382, 'account_id': 2134, 'date': 970317, 'amount': 22932, 'duration': 36, 'payments': 637.0, 'status': 'C'}
# {'loan_id': 6377, 'account_id': 6792, 'date': 970317, 'amount': 17184, 'duration': 12, 'payments': 1432.0, 'status': 'A'}
# {'loan_id': 5931, 'account_id': 4618, 'date': 970317, 'amount': 66696, 'duration': 24, 'payments': 2779.0, 'status': 'D'}
# {'loan_id': 5992, 'account_id': 4863, 'date': 970318, 'amount': 76080, 'duration': 12, 'payments': 6340.0, 'status': 'A'}
# {'loan_id': 5790, 'account_id': 4033, 'date': 970320, 'amount': 84288, 'duration': 48, 'payments': 1756.0, 'status': 'C'}
# {'loan_id': 6753, 'account_id': 8688, 'date': 970320, 'amount': 67980, 'duration': 12, 'payments': 5665.0, 'status': 'A'}
# {'loan_id': 6562, 'account_id': 7674, 'date': 970321, 'amount': 94488, 'duration': 24, 'payments': 3937.0, 'status': 'C'}
# {'loan_id': 7046, 'account_id': 10049, 'date': 970328, 'amount': 91632, 'duration': 12, 'payments': 7636.0, 'status': 'A'}
# {'loan_id': 5868, 'account_id': 4361, 'date': 970329, 'amount': 90156, 'duration': 12, 'payments': 7513.0, 'status': 'A'}
# {'loan_id': 5784, 'account_id': 3967, 'date': 970329, 'amount': 84600, 'duration': 36, 'payments': 2350.0, 'status': 'D'}
# {'loan_id': 5878, 'account_id': 4415, 'date': 970401, 'amount': 74040, 'duration': 12, 'payments': 6170.0, 'status': 'A'}
# {'loan_id': 5110, 'account_id': 675, 'date': 970401, 'amount': 102240, 'duration': 60, 'payments': 1704.0, 'status': 'C'}
# {'loan_id': 5210, 'account_id': 1252, 'date': 970401, 'amount': 148140, 'duration': 36, 'payments': 4115.0, 'status': 'C'}
# {'loan_id': 7230, 'account_id': 10954, 'date': 970402, 'amount': 18720, 'duration': 60, 'payments': 312.0, 'status': 'C'}
# {'loan_id': 5005, 'account_id': 176, 'date': 970410, 'amount': 27456, 'duration': 12, 'payments': 2288.0, 'status': 'A'}
# {'loan_id': 6871, 'account_id': 9225, 'date': 970413, 'amount': 164256, 'duration': 48, 'payments': 3422.0, 'status': 'C'}
# {'loan_id': 5363, 'account_id': 2051, 'date': 970422, 'amount': 293880, 'duration': 60, 'payments': 4898.0, 'status': 'D'}
# {'loan_id': 7253, 'account_id': 11079, 'date': 970426, 'amount': 98304, 'duration': 12, 'payments': 8192.0, 'status': 'A'}
# {'loan_id': 6055, 'account_id': 5181, 'date': 970428, 'amount': 399120, 'duration': 60, 'payments': 6652.0, 'status': 'C'}
# {'loan_id': 5072, 'account_id': 472, 'date': 970428, 'amount': 196800, 'duration': 24, 'payments': 8200.0, 'status': 'D'}
# {'loan_id': 6913, 'account_id': 9377, 'date': 970429, 'amount': 99936, 'duration': 24, 'payments': 4164.0, 'status': 'C'}
# {'loan_id': 6386, 'account_id': 6856, 'date': 970430, 'amount': 124344, 'duration': 36, 'payments': 3454.0, 'status': 'C'}
# {'loan_id': 5634, 'account_id': 3229, 'date': 970501, 'amount': 39024, 'duration': 12, 'payments': 3252.0, 'status': 'A'}
# {'loan_id': 5758, 'account_id': 3859, 'date': 970502, 'amount': 307200, 'duration': 60, 'payments': 5120.0, 'status': 'D'}
# {'loan_id': 6819, 'account_id': 9031, 'date': 970503, 'amount': 50112, 'duration': 24, 'payments': 2088.0, 'status': 'C'}
# {'loan_id': 7088, 'account_id': 10233, 'date': 970503, 'amount': 239160, 'duration': 60, 'payments': 3986.0, 'status': 'C'}
# {'loan_id': 5039, 'account_id': 314, 'date': 970503, 'amount': 66840, 'duration': 24, 'payments': 2785.0, 'status': 'C'}
# {'loan_id': 5532, 'account_id': 2754, 'date': 970504, 'amount': 335280, 'duration': 48, 'payments': 6985.0, 'status': 'C'}
# {'loan_id': 6037, 'account_id': 5118, 'date': 970504, 'amount': 53232, 'duration': 48, 'payments': 1109.0, 'status': 'C'}
# ...
# {'loan_id': 5765, 'account_id': 3875, 'date': 980210, 'amount': 153936, 'duration': 24, 'payments': 6414.0, 'status': 'C'}
# {'loan_id': 5124, 'account_id': 785, 'date': 980212, 'amount': 156096, 'duration': 36, 'payments': 4336.0, 'status': 'C'}
# {'loan_id': 5491, 'account_id': 2545, 'date': 980213, 'amount': 428784, 'duration': 48, 'payments': 8933.0, 'status': 'C'}
# {'loan_id': 6730, 'account_id': 8523, 'date': 980215, 'amount': 93036, 'duration': 12, 'payments': 7753.0, 'status': 'C'}
# {'loan_id': 7151, 'account_id': 10493, 'date': 980218, 'amount': 133800, 'duration': 24, 'payments': 5575.0, 'status': 'C'}
# {'loan_id': 5140, 'account_id': 873, 'date': 980224, 'amount': 178500, 'duration': 60, 'payments': 2975.0, 'status': 'C'}
# {'loan_id': 7171, 'account_id': 10650, 'date': 980224, 'amount': 196224, 'duration': 48, 'payments': 4088.0, 'status': 'C'}
# {'loan_id': 6568, 'account_id': 7713, 'date': 980225, 'amount': 220440, 'duration': 60, 'payments': 3674.0, 'status': 'C'}
# {'loan_id': 6861, 'account_id': 9179, 'date': 980228, 'amount': 215040, 'duration': 60, 'payments': 3584.0, 'status': 'C'}
# {'loan_id': 6855, 'account_id': 9153, 'date': 980301, 'amount': 52236, 'duration': 36, 'payments': 1451.0, 'status': 'C'}
# {'loan_id': 7129, 'account_id': 10404, 'date': 980301, 'amount': 194280, 'duration': 60, 'payments': 3238.0, 'status': 'C'}
# {'loan_id': 5384, 'account_id': 2142, 'date': 980307, 'amount': 23328, 'duration': 12, 'payments': 1944.0, 'status': 'C'}
# {'loan_id': 6859, 'account_id': 9167, 'date': 980307, 'amount': 272220, 'duration': 60, 'payments': 4537.0, 'status': 'C'}
# {'loan_id': 5772, 'account_id': 3906, 'date': 980308, 'amount': 334620, 'duration': 60, 'payments': 5577.0, 'status': 'C'}
# {'loan_id': 5665, 'account_id': 3390, 'date': 980311, 'amount': 40632, 'duration': 12, 'payments': 3386.0, 'status': 'C'}
# {'loan_id': 6495, 'account_id': 7274, 'date': 980312, 'amount': 49044, 'duration': 12, 'payments': 4087.0, 'status': 'C'}
# {'loan_id': 5061, 'account_id': 440, 'date': 980313, 'amount': 84288, 'duration': 48, 'payments': 1756.0, 'status': 'C'}
# {'loan_id': 6948, 'account_id': 9560, 'date': 980315, 'amount': 157068, 'duration': 36, 'payments': 4363.0, 'status': 'C'}
# {'loan_id': 5773, 'account_id': 3907, 'date': 980316, 'amount': 133848, 'duration': 24, 'payments': 5577.0, 'status': 'C'}
# {'loan_id': 6052, 'account_id': 5164, 'date': 980323, 'amount': 22356, 'duration': 36, 'payments': 621.0, 'status': 'C'}
# {'loan_id': 6682, 'account_id': 8225, 'date': 980330, 'amount': 36204, 'duration': 12, 'payments': 3017.0, 'status': 'D'}
# {'loan_id': 6083, 'account_id': 5305, 'date': 980331, 'amount': 240528, 'duration': 48, 'payments': 5011.0, 'status': 'C'}
# {'loan_id': 6962, 'account_id': 9646, 'date': 980402, 'amount': 279072, 'duration': 48, 'payments': 5814.0, 'status': 'C'}
# {'loan_id': 5158, 'account_id': 1004, 'date': 980411, 'amount': 188532, 'duration': 36, 'payments': 5237.0, 'status': 'C'}
# {'loan_id': 6464, 'account_id': 7156, 'date': 980416, 'amount': 49488, 'duration': 24, 'payments': 2062.0, 'status': 'C'}
# {'loan_id': 5172, 'account_id': 1083, 'date': 980416, 'amount': 50976, 'duration': 36, 'payments': 1416.0, 'status': 'C'}
# {'loan_id': 5582, 'account_id': 2982, 'date': 980417, 'amount': 41256, 'duration': 12, 'payments': 3438.0, 'status': 'C'}
# {'loan_id': 6136, 'account_id': 5572, 'date': 980419, 'amount': 140880, 'duration': 60, 'payments': 2348.0, 'status': 'C'}
# {'loan_id': 6235, 'account_id': 6062, 'date': 980419, 'amount': 321360, 'duration': 60, 'payments': 5356.0, 'status': 'C'}
# {'loan_id': 6508, 'account_id': 7437, 'date': 980419, 'amount': 110736, 'duration': 48, 'payments': 2307.0, 'status': 'C'}
# {'loan_id': 4968, 'account_id': 38, 'date': 980419, 'amount': 110736, 'duration': 48, 'payments': 2307.0, 'status': 'C'}
# {'loan_id': 6632, 'account_id': 7990, 'date': 980423, 'amount': 144960, 'duration': 48, 'payments': 3020.0, 'status': 'C'}
# {'loan_id': 7195, 'account_id': 10774, 'date': 980423, 'amount': 339168, 'duration': 48, 'payments': 7066.0, 'status': 'C'}
# {'loan_id': 5525, 'account_id': 2720, 'date': 980427, 'amount': 93888, 'duration': 36, 'payments': 2608.0, 'status': 'C'}
# {'loan_id': 6320, 'account_id': 6495, 'date': 980428, 'amount': 104964, 'duration': 12, 'payments': 8747.0, 'status': 'C'}
# {'loan_id': 6766, 'account_id': 8784, 'date': 980428, 'amount': 74352, 'duration': 24, 'payments': 3098.0, 'status': 'C'}
# {'loan_id': 6872, 'account_id': 9227, 'date': 980429, 'amount': 191580, 'duration': 60, 'payments': 3193.0, 'status': 'C'}
# {'loan_id': 5906, 'account_id': 4533, 'date': 980505, 'amount': 81144, 'duration': 36, 'payments': 2254.0, 'status': 'C'}
# {'loan_id': 7172, 'account_id': 10652, 'date': 980507, 'amount': 45720, 'duration': 12, 'payments': 3810.0, 'status': 'C'}
# {'loan_id': 6571, 'account_id': 7733, 'date': 980512, 'amount': 140064, 'duration': 24, 'payments': 5836.0, 'status': 'C'}
# {'loan_id': 5616, 'account_id': 3143, 'date': 980515, 'amount': 130896, 'duration': 24, 'payments': 5454.0, 'status': 'C'}
# {'loan_id': 6312, 'account_id': 6453, 'date': 980517, 'amount': 10944, 'duration': 36, 'payments': 304.0, 'status': 'C'}
# {'loan_id': 6470, 'account_id': 7181, 'date': 980517, 'amount': 49872, 'duration': 12, 'payments': 4156.0, 'status': 'C'}
# {'loan_id': 5147, 'account_id': 938, 'date': 980521, 'amount': 22260, 'duration': 60, 'payments': 371.0, 'status': 'C'}
# {'loan_id': 5501, 'account_id': 2622, 'date': 980521, 'amount': 136344, 'duration': 24, 'payments': 5681.0, 'status': 'C'}
# {'loan_id': 6436, 'account_id': 7049, 'date': 980522, 'amount': 495180, 'duration': 60, 'payments': 8253.0, 'status': 'C'}
# {'loan_id': 5699, 'account_id': 3562, 'date': 980524, 'amount': 174960, 'duration': 24, 'payments': 7290.0, 'status': 'C'}
# {'loan_id': 5313, 'account_id': 1776, 'date': 980527, 'amount': 43200, 'duration': 24, 'payments': 1800.0, 'status': 'C'}
# {'loan_id': 6234, 'account_id': 6061, 'date': 980528, 'amount': 5148, 'duration': 12, 'payments': 429.0, 'status': 'C'}
# {'loan_id': 6569, 'account_id': 7721, 'date': 980528, 'amount': 45456, 'duration': 12, 'payments': 3788.0, 'status': 'C'}
# {'loan_id': 7202, 'account_id': 10812, 'date': 980529, 'amount': 140688, 'duration': 48, 'payments': 2931.0, 'status': 'C'}
# {'loan_id': 5683, 'account_id': 3460, 'date': 980529, 'amount': 140688, 'duration': 48, 'payments': 2931.0, 'status': 'C'}
# {'loan_id': 5034, 'account_id': 303, 'date': 980530, 'amount': 112752, 'duration': 36, 'payments': 3132.0, 'status': 'C'}
# {'loan_id': 5435, 'account_id': 2279, 'date': 980601, 'amount': 314688, 'duration': 48, 'payments': 6556.0, 'status': 'C'}
# {'loan_id': 5815, 'account_id': 4116, 'date': 980603, 'amount': 151200, 'duration': 36, 'payments': 4200.0, 'status': 'C'}
# {'loan_id': 5589, 'account_id': 3005, 'date': 980605, 'amount': 390000, 'duration': 48, 'payments': 8125.0, 'status': 'C'}
# {'loan_id': 6746, 'account_id': 8639, 'date': 980606, 'amount': 185640, 'duration': 60, 'payments': 3094.0, 'status': 'C'}
# {'loan_id': 6790, 'account_id': 8919, 'date': 980608, 'amount': 76104, 'duration': 24, 'payments': 3171.0, 'status': 'C'}
# {'loan_id': 6857, 'account_id': 9159, 'date': 980608, 'amount': 69600, 'duration': 48, 'payments': 1450.0, 'status': 'C'}
# {'loan_id': 6450, 'account_id': 7099, 'date': 980610, 'amount': 234336, 'duration': 48, 'payments': 4882.0, 'status': 'C'}
# {'loan_id': 7221, 'account_id': 10915, 'date': 980611, 'amount': 152460, 'duration': 60, 'payments': 2541.0, 'status': 'C'}
# {'loan_id': 5527, 'account_id': 2728, 'date': 980615, 'amount': 156420, 'duration': 60, 'payments': 2607.0, 'status': 'C'}
# {'loan_id': 5620, 'account_id': 3161, 'date': 980616, 'amount': 30012, 'duration': 12, 'payments': 2501.0, 'status': 'C'}
# {'loan_id': 6215, 'account_id': 5944, 'date': 980618, 'amount': 78720, 'duration': 48, 'payments': 1640.0, 'status': 'C'}
# {'loan_id': 7167, 'account_id': 10644, 'date': 980618, 'amount': 269964, 'duration': 36, 'payments': 7499.0, 'status': 'C'}
# {'loan_id': 5823, 'account_id': 4144, 'date': 980621, 'amount': 212976, 'duration': 36, 'payments': 5916.0, 'status': 'C'}
# {'loan_id': 6207, 'account_id': 5912, 'date': 980623, 'amount': 184620, 'duration': 60, 'payments': 3077.0, 'status': 'C'}
# {'loan_id': 6932, 'account_id': 9491, 'date': 980625, 'amount': 225504, 'duration': 48, 'payments': 4698.0, 'status': 'C'}
# {'loan_id': 5669, 'account_id': 3403, 'date': 980627, 'amount': 71820, 'duration': 36, 'payments': 1995.0, 'status': 'C'}
# {'loan_id': 5154, 'account_id': 993, 'date': 980701, 'amount': 108720, 'duration': 60, 'payments': 1812.0, 'status': 'C'}
# {'loan_id': 7168, 'account_id': 10645, 'date': 980705, 'amount': 208332, 'duration': 36, 'payments': 5787.0, 'status': 'C'}
# {'loan_id': 5585, 'account_id': 2988, 'date': 980708, 'amount': 88608, 'duration': 12, 'payments': 7384.0, 'status': 'C'}
# {'loan_id': 7200, 'account_id': 10799, 'date': 980711, 'amount': 31140, 'duration': 60, 'payments': 519.0, 'status': 'C'}
# {'loan_id': 6539, 'account_id': 7559, 'date': 980711, 'amount': 12792, 'duration': 12, 'payments': 1066.0, 'status': 'C'}
# {'loan_id': 5774, 'account_id': 3916, 'date': 980712, 'amount': 96984, 'duration': 36, 'payments': 2694.0, 'status': 'C'}
# {'loan_id': 6357, 'account_id': 6706, 'date': 980712, 'amount': 64860, 'duration': 60, 'payments': 1081.0, 'status': 'C'}
# {'loan_id': 5042, 'account_id': 330, 'date': 980712, 'amount': 331584, 'duration': 48, 'payments': 6908.0, 'status': 'C'}
# {'loan_id': 5015, 'account_id': 226, 'date': 980712, 'amount': 109344, 'duration': 12, 'payments': 9112.0, 'status': 'C'}
# {'loan_id': 5354, 'account_id': 2000, 'date': 980714, 'amount': 290820, 'duration': 60, 'payments': 4847.0, 'status': 'C'}
# {'loan_id': 6054, 'account_id': 5180, 'date': 980716, 'amount': 58764, 'duration': 12, 'payments': 4897.0, 'status': 'C'}
# {'loan_id': 7295, 'account_id': 11328, 'date': 980718, 'amount': 280440, 'duration': 60, 'payments': 4674.0, 'status': 'C'}
# {'loan_id': 5365, 'account_id': 2055, 'date': 980719, 'amount': 271260, 'duration': 60, 'payments': 4521.0, 'status': 'C'}
# {'loan_id': 6755, 'account_id': 8713, 'date': 980724, 'amount': 170700, 'duration': 60, 'payments': 2845.0, 'status': 'C'}
# {'loan_id': 5991, 'account_id': 4858, 'date': 980727, 'amount': 335184, 'duration': 48, 'payments': 6983.0, 'status': 'D'}
# {'loan_id': 7035, 'account_id': 10005, 'date': 980729, 'amount': 210744, 'duration': 36, 'payments': 5854.0, 'status': 'C'}
# {'loan_id': 5893, 'account_id': 4467, 'date': 980803, 'amount': 86184, 'duration': 36, 'payments': 2394.0, 'status': 'C'}
# {'loan_id': 7164, 'account_id': 10613, 'date': 980815, 'amount': 249792, 'duration': 48, 'payments': 5204.0, 'status': 'C'}
# {'loan_id': 5304, 'account_id': 1718, 'date': 980820, 'amount': 172272, 'duration': 24, 'payments': 7178.0, 'status': 'C'}
# {'loan_id': 5561, 'account_id': 2910, 'date': 980829, 'amount': 437460, 'duration': 60, 'payments': 7291.0, 'status': 'C'}
# {'loan_id': 5520, 'account_id': 2699, 'date': 980830, 'amount': 231168, 'duration': 48, 'payments': 4816.0, 'status': 'C'}
# {'loan_id': 5241, 'account_id': 1389, 'date': 980902, 'amount': 125472, 'duration': 24, 'payments': 5228.0, 'status': 'C'}
# {'loan_id': 7096, 'account_id': 10257, 'date': 980902, 'amount': 37812, 'duration': 12, 'payments': 3151.0, 'status': 'C'}
# {'loan_id': 6078, 'account_id': 5283, 'date': 980909, 'amount': 170832, 'duration': 48, 'payments': 3559.0, 'status': 'C'}
# {'loan_id': 5046, 'account_id': 349, 'date': 980909, 'amount': 42816, 'duration': 12, 'payments': 3568.0, 'status': 'C'}
# {'loan_id': 5334, 'account_id': 1876, 'date': 980910, 'amount': 209040, 'duration': 24, 'payments': 8710.0, 'status': 'C'}
# {'loan_id': 6969, 'account_id': 9673, 'date': 980912, 'amount': 88200, 'duration': 36, 'payments': 2450.0, 'status': 'C'}
# {'loan_id': 6821, 'account_id': 9037, 'date': 980915, 'amount': 321936, 'duration': 48, 'payments': 6707.0, 'status': 'C'}
# {'loan_id': 5760, 'account_id': 3862, 'date': 980918, 'amount': 74916, 'duration': 36, 'payments': 2081.0, 'status': 'C'}
# {'loan_id': 5614, 'account_id': 3137, 'date': 980921, 'amount': 253560, 'duration': 60, 'payments': 4226.0, 'status': 'C'}
# {'loan_id': 7091, 'account_id': 10243, 'date': 980922, 'amount': 113436, 'duration': 36, 'payments': 3151.0, 'status': 'C'}
# {'loan_id': 5698, 'account_id': 3556, 'date': 980922, 'amount': 174840, 'duration': 60, 'payments': 2914.0, 'status': 'C'}
# {'loan_id': 5169, 'account_id': 1068, 'date': 980924, 'amount': 253200, 'duration': 60, 'payments': 4220.0, 'status': 'C'}
# {'loan_id': 7294, 'account_id': 11327, 'date': 980927, 'amount': 39168, 'duration': 24, 'payments': 1632.0, 'status': 'C'}
# {'loan_id': 5318, 'account_id': 1808, 'date': 980930, 'amount': 385584, 'duration': 48, 'payments': 8033.0, 'status': 'C'}
# {'loan_id': 5368, 'account_id': 2073, 'date': 981005, 'amount': 44640, 'duration': 24, 'payments': 1860.0, 'status': 'C'}
# {'loan_id': 6923, 'account_id': 9433, 'date': 981005, 'amount': 44640, 'duration': 24, 'payments': 1860.0, 'status': 'C'}
# {'loan_id': 5463, 'account_id': 2413, 'date': 981006, 'amount': 17952, 'duration': 12, 'payments': 1496.0, 'status': 'C'}
# {'loan_id': 5265, 'account_id': 1498, 'date': 981007, 'amount': 165780, 'duration': 60, 'payments': 2763.0, 'status': 'C'}
# {'loan_id': 6321, 'account_id': 6505, 'date': 981008, 'amount': 38496, 'duration': 12, 'payments': 3208.0, 'status': 'C'}
# {'loan_id': 5226, 'account_id': 1318, 'date': 981011, 'amount': 185544, 'duration': 36, 'payments': 5154.0, 'status': 'C'}
# {'loan_id': 6868, 'account_id': 9208, 'date': 981012, 'amount': 82128, 'duration': 24, 'payments': 3422.0, 'status': 'C'}
# {'loan_id': 4967, 'account_id': 37, 'date': 981014, 'amount': 318480, 'duration': 60, 'payments': 5308.0, 'status': 'D'}
# {'loan_id': 5293, 'account_id': 1656, 'date': 981029, 'amount': 189792, 'duration': 48, 'payments': 3954.0, 'status': 'C'}
# {'loan_id': 5865, 'account_id': 4354, 'date': 981030, 'amount': 327660, 'duration': 60, 'payments': 5461.0, 'status': 'C'}
# {'loan_id': 5841, 'account_id': 4268, 'date': 981104, 'amount': 41988, 'duration': 12, 'payments': 3499.0, 'status': 'C'}
# {'loan_id': 5526, 'account_id': 2725, 'date': 981108, 'amount': 69624, 'duration': 36, 'payments': 1934.0, 'status': 'C'}
# {'loan_id': 6852, 'account_id': 9140, 'date': 981110, 'amount': 16032, 'duration': 48, 'payments': 334.0, 'status': 'C'}
# {'loan_id': 6469, 'account_id': 7180, 'date': 981117, 'amount': 99744, 'duration': 24, 'payments': 4156.0, 'status': 'C'}
# {'loan_id': 6168, 'account_id': 5698, 'date': 981121, 'amount': 99216, 'duration': 36, 'payments': 2756.0, 'status': 'C'}
# {'loan_id': 7292, 'account_id': 11317, 'date': 981122, 'amount': 317460, 'duration': 60, 'payments': 5291.0, 'status': 'C'}
# {'loan_id': 5036, 'account_id': 309, 'date': 981125, 'amount': 91248, 'duration': 48, 'payments': 1901.0, 'status': 'C'}
# {'loan_id': 5644, 'account_id': 3293, 'date': 981127, 'amount': 276084, 'duration': 36, 'payments': 7669.0, 'status': 'C'}
# {'loan_id': 6856, 'account_id': 9156, 'date': 981201, 'amount': 163332, 'duration': 36, 'payments': 4537.0, 'status': 'C'}
# {'loan_id': 5428, 'account_id': 2262, 'date': 981202, 'amount': 230220, 'duration': 36, 'payments': 6395.0, 'status': 'C'}
# {'loan_id': 5027, 'account_id': 276, 'date': 981202, 'amount': 160920, 'duration': 36, 'payments': 4470.0, 'status': 'C'}
# {'loan_id': 4989, 'account_id': 105, 'date': 981205, 'amount': 352704, 'duration': 48, 'payments': 7348.0, 'status': 'C'}
# {'loan_id': 5221, 'account_id': 1284, 'date': 981205, 'amount': 52512, 'duration': 12, 'payments': 4376.0, 'status': 'C'}
# {'loan_id': 6402, 'account_id': 6922, 'date': 981206, 'amount': 139488, 'duration': 24, 'payments': 5812.0, 'status': 'C'}
# {'loan_id': 5346, 'account_id': 1928, 'date': 981206, 'amount': 55632, 'duration': 24, 'payments': 2318.0, 'status': 'C'}
# {'loan_id': 6748, 'account_id': 8645, 'date': 981208, 'amount': 240900, 'duration': 60, 'payments': 4015.0, 'status': 'C'}

# %%
# If we just want the values in tuples instead of dictionary with column names, we can do the following

with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    for row in result:
        print(row)
# Out:
# (5314, 1787, 930705, 96396, 12, 8033.0, 'B')
# (5316, 1801, 930711, 165960, 36, 4610.0, 'A')
# (6863, 9188, 930728, 127080, 60, 2118.0, 'A')
# (5325, 1843, 930803, 105804, 36, 2939.0, 'A')
# (7240, 11013, 930906, 274740, 60, 4579.0, 'A')
# (6687, 8261, 930913, 87840, 24, 3660.0, 'A')
# (7284, 11265, 930915, 52788, 12, 4399.0, 'A')
# (6111, 5428, 930924, 174744, 24, 7281.0, 'B')
# (7235, 10973, 931013, 154416, 48, 3217.0, 'A')
# (5997, 4894, 931104, 117024, 24, 4876.0, 'A')
# (7121, 10364, 931110, 21924, 36, 609.0, 'A')
# (6077, 5270, 931122, 79608, 24, 3317.0, 'A')
# (6228, 6034, 931201, 464520, 60, 7742.0, 'B')
# (6356, 6701, 931208, 95400, 36, 2650.0, 'A')
# (5523, 2705, 931208, 93888, 36, 2608.0, 'A')
# (6456, 7123, 931209, 47016, 12, 3918.0, 'A')
# (7104, 10320, 931213, 259740, 60, 4329.0, 'A')
# (6820, 9034, 931216, 38148, 12, 3179.0, 'A')
# (6876, 9236, 931221, 86616, 12, 7218.0, 'A')
# (7097, 10266, 931223, 75624, 24, 3151.0, 'B')
# (4959, 2, 940105, 80952, 24, 3373.0, 'A')
# (6499, 7401, 940105, 80952, 24, 3373.0, 'A')
# (5479, 2486, 940110, 24516, 12, 2043.0, 'A')
# (5170, 1071, 940120, 253200, 60, 4220.0, 'C')
# (6721, 8475, 940121, 21072, 24, 878.0, 'A')
# (7259, 11111, 940131, 108144, 36, 3004.0, 'A')
# (5285, 1603, 940206, 78936, 12, 6578.0, 'A')
# (5189, 1166, 940207, 149040, 48, 3105.0, 'A')
# (6650, 8073, 940217, 49320, 12, 4110.0, 'B')
# (7226, 10940, 940223, 197748, 36, 5493.0, 'A')
# (6087, 5313, 940227, 300660, 60, 5011.0, 'C')
# (7262, 11135, 940301, 182628, 36, 5073.0, 'A')
# (5519, 2694, 940308, 91632, 12, 7636.0, 'A')
# (6577, 7753, 940311, 51696, 24, 2154.0, 'A')
# (6509, 7445, 940315, 55368, 24, 2307.0, 'A')
# (6520, 7485, 940316, 91200, 24, 3800.0, 'A')
# (6699, 8330, 940330, 7656, 24, 319.0, 'A')
# (6336, 6555, 940331, 212400, 36, 5900.0, 'A')
# (7055, 10079, 940406, 167100, 60, 2785.0, 'C')
# (6103, 5385, 940407, 149340, 60, 2489.0, 'C')
# (6202, 5891, 940418, 65184, 12, 5432.0, 'A')
# (7066, 10131, 940502, 215388, 36, 5983.0, 'B')
# (6696, 8321, 940509, 89040, 60, 1484.0, 'C')
# (6072, 5256, 940510, 193968, 36, 5388.0, 'A')
# (5130, 813, 940511, 24312, 12, 2026.0, 'A')
# (5568, 2933, 940517, 272520, 60, 4542.0, 'C')
# (6678, 8173, 940520, 80340, 12, 6695.0, 'A')
# (6998, 9833, 940521, 97632, 12, 8136.0, 'A')
# (6580, 7769, 940522, 196080, 48, 4085.0, 'A')
# (6316, 6473, 940526, 76908, 12, 6409.0, 'B')
# (6512, 7454, 940526, 63312, 48, 1319.0, 'A')
# (6407, 6930, 940526, 25944, 24, 1081.0, 'A')
# (5002, 173, 940531, 104808, 12, 8734.0, 'A')
# (6647, 8051, 940601, 208320, 48, 4340.0, 'A')
# (7137, 10439, 940603, 151560, 24, 6315.0, 'A')
# (6903, 9337, 940604, 52128, 24, 2172.0, 'A')
# (5918, 4576, 940604, 300204, 36, 8339.0, 'A')
# (6642, 8027, 940605, 77640, 12, 6470.0, 'A')
# (6210, 5927, 940606, 87216, 48, 1817.0, 'B')
# (6279, 6273, 940607, 87360, 24, 3640.0, 'A')
# (7249, 11065, 940612, 69360, 48, 1445.0, 'A')
# (6736, 8558, 940614, 288360, 60, 4806.0, 'C')
# (6112, 5442, 940617, 174744, 24, 7281.0, 'B')
# (5319, 1811, 940623, 239460, 60, 3991.0, 'C')
# (6596, 7844, 940625, 91584, 24, 3816.0, 'A')
# (5837, 4260, 940629, 244560, 60, 4076.0, 'C')
# (5657, 3354, 940705, 4980, 12, 415.0, 'A')
# (5533, 2762, 940705, 111384, 24, 4641.0, 'A')
# (6232, 6051, 940708, 276660, 36, 7685.0, 'B')
# (6888, 9265, 940711, 39576, 12, 3298.0, 'A')
# (6066, 5228, 940711, 173808, 24, 7242.0, 'A')
# (5549, 2824, 940716, 50460, 60, 841.0, 'C')
# (5060, 426, 940719, 252060, 60, 4201.0, 'D')
# (6004, 4937, 940723, 143904, 24, 5996.0, 'A')
# (5126, 790, 940724, 208128, 48, 4336.0, 'B')
# (7220, 10911, 940728, 131292, 36, 3647.0, 'A')
# (6668, 8129, 940730, 74736, 36, 2076.0, 'A')
# (5395, 2176, 940730, 299088, 36, 8308.0, 'B')
# (6836, 9093, 940803, 189300, 60, 3155.0, 'C')
# (6064, 5215, 940804, 14628, 12, 1219.0, 'A')
# (6919, 9403, 940805, 120888, 36, 3358.0, 'A')
# (6841, 9104, 940807, 172080, 48, 3585.0, 'A')
# (6038, 5120, 940810, 323472, 48, 6739.0, 'A')
# (6729, 8519, 940811, 74688, 12, 6224.0, 'A')
# (7198, 10788, 940823, 45768, 12, 3814.0, 'A')
# (6686, 8260, 940825, 224604, 36, 6239.0, 'A')
# (5836, 4259, 940827, 79632, 24, 3318.0, 'A')
# (7061, 10105, 940827, 121896, 24, 5079.0, 'A')
# (5595, 3050, 940902, 82896, 12, 6908.0, 'A')
# (5723, 3674, 940910, 23628, 12, 1969.0, 'A')
# (6120, 5481, 940911, 209184, 48, 4358.0, 'A')
# (6895, 9307, 940919, 41904, 12, 3492.0, 'A')
# (5882, 4427, 940926, 87816, 12, 7318.0, 'A')
# (5754, 3834, 940928, 23052, 12, 1921.0, 'A')
# (6594, 7824, 940928, 189696, 24, 7904.0, 'B')
# (6738, 8566, 940929, 230220, 36, 6395.0, 'B')
# (6624, 7965, 940930, 71460, 12, 5955.0, 'A')
# (6216, 5952, 940930, 141240, 24, 5885.0, 'A')
# (6229, 6040, 941002, 11736, 24, 489.0, 'A')
# (5887, 4448, 941003, 192744, 36, 5354.0, 'A')
# (6808, 8982, 941012, 227880, 36, 6330.0, 'A')
# (6297, 6363, 941025, 17508, 12, 1459.0, 'A')
# (5161, 1012, 941028, 98184, 24, 4091.0, 'A')
# (5390, 2167, 941030, 170256, 24, 7094.0, 'A')
# (6150, 5622, 941102, 83016, 12, 6918.0, 'A')
# (6223, 5991, 941103, 61056, 48, 1272.0, 'A')
# (5032, 290, 941103, 123696, 48, 2577.0, 'A')
# (6253, 6148, 941104, 59760, 24, 2490.0, 'A')
# (6460, 7133, 941106, 48672, 36, 1352.0, 'A')
# (6645, 8041, 941106, 140400, 36, 3900.0, 'A')
# (5176, 1106, 941112, 192552, 24, 8023.0, 'B')
# (5269, 1527, 941119, 164052, 36, 4557.0, 'B')
# (5351, 1978, 941204, 205200, 36, 5700.0, 'A')
# (5861, 4337, 941208, 51408, 24, 2142.0, 'A')
# (5450, 2345, 941211, 199680, 60, 3328.0, 'C')
# (7142, 10451, 941219, 482940, 60, 8049.0, 'D')
# (6306, 6425, 941220, 36684, 12, 3057.0, 'A')
# (6272, 6226, 941220, 398640, 60, 6644.0, 'C')
# (5044, 344, 941221, 100980, 60, 1683.0, 'C')
# (5576, 2962, 941221, 31248, 12, 2604.0, 'A')
# (7192, 10738, 941221, 115992, 36, 3222.0, 'A')
# (5739, 3747, 950102, 76380, 12, 6365.0, 'A')
# (6526, 7523, 950103, 288468, 36, 8013.0, 'A')
# (5624, 3166, 950103, 177744, 48, 3703.0, 'D')
# (6244, 6118, 950108, 270648, 36, 7518.0, 'B')
# (5131, 816, 950108, 48624, 24, 2026.0, 'A')
# (6960, 9640, 950111, 76416, 24, 3184.0, 'A')
# (6358, 6715, 950114, 137880, 60, 2298.0, 'D')
# (5418, 2245, 950116, 347952, 48, 7249.0, 'C')
# (6598, 7857, 950118, 68112, 12, 5676.0, 'A')
# (5464, 2419, 950130, 95808, 12, 7984.0, 'A')
# (6591, 7819, 950202, 20832, 48, 434.0, 'C')
# (5724, 3678, 950205, 316140, 60, 5269.0, 'D')
# (6315, 6472, 950206, 43164, 12, 3597.0, 'A')
# (5876, 4413, 950208, 221280, 48, 4610.0, 'C')
# (6986, 9750, 950211, 151728, 48, 3161.0, 'D')
# (6294, 6353, 950212, 79920, 60, 1332.0, 'C')
# (5132, 817, 950217, 538500, 60, 8975.0, 'C')
# (5877, 4414, 950223, 97224, 24, 4051.0, 'A')
# (6227, 6030, 950304, 28248, 24, 1177.0, 'A')
# (7241, 11021, 950304, 168984, 24, 7041.0, 'B')
# (6737, 8564, 950311, 76680, 24, 3195.0, 'A')
# (7004, 9869, 950315, 331560, 60, 5526.0, 'C')
# (6169, 5700, 950316, 103680, 60, 1728.0, 'D')
# (5208, 1247, 950316, 99696, 48, 2077.0, 'D')
# (6694, 8316, 950319, 134784, 24, 5616.0, 'A')
# (5599, 3064, 950321, 15420, 12, 1285.0, 'A')
# (6546, 7607, 950327, 31728, 24, 1322.0, 'A')
# (5414, 2228, 950329, 185952, 48, 3874.0, 'C')
# (5453, 2361, 950401, 156672, 36, 4352.0, 'A')
# (5740, 3752, 950402, 18564, 12, 1547.0, 'A')
# (5804, 4079, 950405, 158976, 48, 3312.0, 'C')
# (6745, 8625, 950410, 47304, 24, 1971.0, 'A')
# (6950, 9591, 950411, 104712, 24, 4363.0, 'A')
# (6996, 9828, 950413, 126600, 24, 5275.0, 'A')
# (5352, 1993, 950415, 68400, 12, 5700.0, 'B')
# (6151, 5628, 950425, 225420, 60, 3757.0, 'C')
# (5310, 1762, 950428, 248148, 36, 6893.0, 'A')
# (5045, 347, 950501, 187224, 24, 7801.0, 'B')
# (6929, 9472, 950508, 36396, 12, 3033.0, 'A')
# (5151, 960, 950524, 189060, 60, 3151.0, 'C')
# (5212, 1256, 950529, 71064, 36, 1974.0, 'A')
# (5138, 854, 950530, 87216, 48, 1817.0, 'C')
# (5713, 3629, 950530, 158760, 60, 2646.0, 'C')
# (6704, 8377, 950601, 417060, 60, 6951.0, 'C')
# (6474, 7190, 950606, 63360, 60, 1056.0, 'C')
# (6676, 8159, 950613, 29784, 24, 1241.0, 'A')
# (6965, 9656, 950613, 139536, 24, 5814.0, 'A')
# (6725, 8489, 950623, 265320, 36, 7370.0, 'A')
# (7166, 10630, 950624, 198240, 24, 8260.0, 'A')
# (7138, 10440, 950703, 60000, 60, 1000.0, 'C')
# (5970, 4774, 950709, 465072, 48, 9689.0, 'C')
# (6157, 5650, 950710, 98592, 24, 4108.0, 'A')
# (6153, 5632, 950725, 285600, 60, 4760.0, 'C')
# (5693, 3489, 950801, 44088, 24, 1837.0, 'A')
# (5922, 4580, 950805, 20220, 12, 1685.0, 'A')
# (5959, 4727, 950811, 107640, 24, 4485.0, 'A')
# (5980, 4825, 950818, 21396, 12, 1783.0, 'A')
# (6764, 8776, 950826, 33984, 48, 708.0, 'C')
# (5237, 1375, 950829, 45336, 24, 1889.0, 'A')
# (6726, 8492, 950903, 85860, 60, 1431.0, 'C')
# (6933, 9493, 950909, 188688, 48, 3931.0, 'C')
# (5145, 915, 950916, 309552, 48, 6449.0, 'C')
# (7008, 9897, 950922, 36168, 12, 3014.0, 'A')
# (7227, 10942, 951002, 314520, 60, 5242.0, 'C')
# (6600, 7861, 951008, 21852, 36, 607.0, 'A')
# (6712, 8405, 951014, 266220, 60, 4437.0, 'C')
# (7057, 10093, 951020, 231696, 36, 6436.0, 'A')
# (7176, 10663, 951028, 260028, 36, 7223.0, 'A')
# (7304, 11349, 951029, 419880, 60, 6998.0, 'C')
# (6362, 6738, 951031, 37908, 12, 3159.0, 'A')
# (5880, 4423, 951031, 73836, 36, 2051.0, 'A')
# (6535, 7546, 951102, 41952, 12, 3496.0, 'A')
# (5449, 2343, 951104, 99336, 24, 4139.0, 'A')
# (6342, 6609, 951112, 60156, 36, 1671.0, 'B')
# (5409, 2218, 951118, 182040, 60, 3034.0, 'C')
# (6955, 9627, 951122, 244368, 48, 5091.0, 'C')
# (6985, 9731, 951122, 113796, 36, 3161.0, 'A')
# (5125, 789, 951123, 73056, 48, 1522.0, 'C')
# (5805, 4081, 951128, 137904, 24, 5746.0, 'B')
# (6185, 5774, 951128, 31176, 24, 1299.0, 'A')
# (7243, 11042, 951204, 217152, 36, 6032.0, 'A')
# (6403, 6924, 951205, 194880, 48, 4060.0, 'C')
# (6578, 7765, 951211, 27984, 12, 2332.0, 'A')
# (5413, 2227, 951212, 92976, 24, 3874.0, 'A')
# (6949, 9583, 951212, 104712, 24, 4363.0, 'A')
# (6545, 7606, 951212, 191880, 60, 3198.0, 'C')
# (6178, 5742, 951216, 232560, 48, 4845.0, 'C')
# (5160, 1011, 951218, 204000, 60, 3400.0, 'C')
# (6785, 8899, 951225, 125340, 60, 2089.0, 'C')
# (6540, 7562, 951231, 309600, 48, 6450.0, 'C')
# (6589, 7815, 960101, 189696, 24, 7904.0, 'A')
# (5900, 4503, 960101, 135360, 48, 2820.0, 'C')
# (5999, 4907, 960103, 98832, 48, 2059.0, 'C')
# (6043, 5126, 960111, 20352, 48, 424.0, 'C')
# (5482, 2496, 960112, 165120, 60, 2752.0, 'C')
# (7263, 11138, 960119, 89880, 24, 3745.0, 'A')
# (6013, 4995, 960203, 128988, 36, 3583.0, 'D')
# (5750, 3804, 960208, 63252, 12, 5271.0, 'A')
# (6027, 5066, 960210, 61656, 24, 2569.0, 'B')
# (6303, 6400, 960212, 72408, 24, 3017.0, 'B')
# (7213, 10884, 960213, 113544, 36, 3154.0, 'C')
# (6659, 8092, 960220, 56100, 60, 935.0, 'C')
# (6175, 5735, 960221, 290700, 60, 4845.0, 'D')
# (5610, 3112, 960224, 123216, 48, 2567.0, 'C')
# (5563, 2912, 960229, 380160, 60, 6336.0, 'C')
# (5989, 4852, 960304, 213300, 36, 5925.0, 'C')
# (6698, 8327, 960310, 247728, 48, 5161.0, 'C')
# (5312, 1772, 960313, 202788, 36, 5633.0, 'C')
# (7189, 10728, 960321, 154656, 48, 3222.0, 'C')
# (6816, 9017, 960326, 100224, 48, 2088.0, 'D')
# (6137, 5574, 960410, 44628, 12, 3719.0, 'A')
# (5128, 808, 960411, 215616, 48, 4492.0, 'D')
# (5470, 2456, 960415, 200976, 48, 4187.0, 'C')
# (5593, 3037, 960418, 277884, 36, 7719.0, 'D')
# (5350, 1967, 960421, 249312, 48, 5194.0, 'C')
# (6063, 5213, 960425, 320976, 48, 6687.0, 'D')
# (6501, 7418, 960429, 30276, 12, 2523.0, 'B')
# (5452, 2352, 960429, 49440, 60, 824.0, 'C')
# (4961, 19, 960429, 30276, 12, 2523.0, 'B')
# (4973, 67, 960502, 165960, 24, 6915.0, 'A')
# (6190, 5794, 960506, 123600, 60, 2060.0, 'C')
# (6715, 8411, 960506, 220620, 60, 3677.0, 'C')
# (5892, 4462, 960514, 66480, 24, 2770.0, 'B')
# (6550, 7614, 960518, 320592, 48, 6679.0, 'C')
# (5706, 3608, 960524, 161496, 36, 4486.0, 'C')
# (5148, 940, 960529, 284280, 60, 4738.0, 'C')
# (6734, 8547, 960530, 173016, 36, 4806.0, 'C')
# (6109, 5422, 960603, 368880, 60, 6148.0, 'C')
# (6961, 9645, 960606, 176148, 36, 4893.0, 'C')
# (6810, 9006, 960608, 186384, 48, 3883.0, 'C')
# (5494, 2572, 960613, 360000, 48, 7500.0, 'C')
# (5311, 1766, 960615, 30060, 60, 501.0, 'C')
# (5445, 2322, 960629, 46320, 24, 1930.0, 'A')
# (5301, 1698, 960706, 141948, 36, 3943.0, 'C')
# (7034, 10001, 960711, 19044, 36, 529.0, 'C')
# (6751, 8680, 960714, 85716, 36, 2381.0, 'C')
# (6667, 8127, 960715, 155880, 24, 6495.0, 'A')
# (6130, 5541, 960718, 32640, 48, 680.0, 'C')
# (5429, 2268, 960718, 20196, 36, 561.0, 'C')
# (5725, 3679, 960723, 444864, 48, 9268.0, 'C')
# (6019, 5033, 960725, 11400, 12, 950.0, 'A')
# (6421, 6985, 960725, 96768, 36, 2688.0, 'C')
# (6992, 9790, 960727, 133968, 48, 2791.0, 'C')
# (5136, 846, 960728, 187104, 24, 7796.0, 'A')
# (5337, 1886, 960731, 162468, 36, 4513.0, 'C')
# (5495, 2580, 960802, 89340, 60, 1489.0, 'C')
# (7013, 9928, 960802, 89340, 60, 1489.0, 'C')
# (6012, 4994, 960803, 258444, 36, 7179.0, 'C')
# (6471, 7184, 960804, 155640, 24, 6485.0, 'A')
# (6296, 6358, 960806, 270384, 48, 5633.0, 'C')
# (7305, 11359, 960806, 54024, 12, 4502.0, 'A')
# (6144, 5593, 960809, 44376, 12, 3698.0, 'A')
# (6283, 6289, 960811, 85632, 48, 1784.0, 'C')
# (7246, 11054, 960820, 148920, 60, 2482.0, 'C')
# (5088, 544, 960822, 91152, 24, 3798.0, 'A')
# (5988, 4851, 960822, 141648, 24, 5902.0, 'A')
# (5282, 1583, 960824, 388512, 48, 8094.0, 'D')
# (5938, 4650, 960825, 402000, 60, 6700.0, 'C')
# (5606, 3084, 960828, 253512, 36, 7042.0, 'D')
# (5385, 2143, 960909, 71460, 36, 1985.0, 'C')
# (6865, 9199, 960911, 29448, 12, 2454.0, 'B')
# (5586, 2994, 960914, 48744, 36, 1354.0, 'C')
# (6302, 6397, 960916, 181020, 60, 3017.0, 'C')
# (7194, 10762, 960917, 68832, 36, 1912.0, 'C')
# (6461, 7136, 960919, 74124, 36, 2059.0, 'C')
# (6732, 8533, 960919, 174048, 48, 3626.0, 'C')
# (6613, 7926, 960922, 84120, 24, 3505.0, 'A')
# (7036, 10019, 960925, 194940, 36, 5415.0, 'C')
# (5897, 4476, 960925, 15192, 24, 633.0, 'A')
# (6995, 9814, 960926, 96168, 12, 8014.0, 'A')
# (5415, 2236, 960926, 139464, 36, 3874.0, 'D')
# (7136, 10436, 960928, 54396, 36, 1511.0, 'C')
# (7271, 11186, 961002, 392460, 60, 6541.0, 'C')
# (5375, 2106, 961003, 101520, 12, 8460.0, 'A')
# (5635, 3230, 961004, 77184, 36, 2144.0, 'C')
# (6817, 9024, 961004, 70656, 48, 1472.0, 'C')
# (5923, 4585, 961010, 64656, 48, 1347.0, 'C')
# (5329, 1862, 961016, 396120, 60, 6602.0, 'C')
# (6644, 8039, 961020, 93600, 24, 3900.0, 'A')
# (6354, 6688, 961023, 22968, 36, 638.0, 'C')
# (5082, 501, 961024, 262980, 60, 4383.0, 'C')
# (6585, 7795, 961029, 372120, 60, 6202.0, 'C')
# (6921, 9422, 961029, 86184, 12, 7182.0, 'A')
# (5366, 2062, 961029, 86184, 12, 7182.0, 'A')
# (5886, 4447, 961031, 192744, 36, 5354.0, 'C')
# (5741, 3754, 961103, 68544, 24, 2856.0, 'A')
# (4996, 132, 961106, 88440, 12, 7370.0, 'A')
# (6015, 5001, 961109, 110112, 24, 4588.0, 'A')
# (6309, 6434, 961111, 110136, 24, 4589.0, 'A')
# (6073, 5263, 961112, 276300, 60, 4605.0, 'C')
# (6006, 4948, 961115, 359760, 60, 5996.0, 'C')
# (5611, 3115, 961115, 321180, 60, 5353.0, 'C')
# (6944, 9548, 961115, 46176, 48, 962.0, 'C')
# (7101, 10297, 961118, 421008, 48, 8771.0, 'C')
# (6599, 7859, 961119, 72120, 12, 6010.0, 'A')
# (6940, 9510, 961122, 228276, 36, 6341.0, 'C')
# (5209, 1250, 961125, 182640, 48, 3805.0, 'C')
# (5388, 2153, 961128, 61560, 12, 5130.0, 'A')
# (6011, 4981, 961128, 179328, 48, 3736.0, 'C')
# (5591, 3021, 961204, 155616, 48, 3242.0, 'C')
# (7154, 10520, 961205, 417600, 60, 6960.0, 'C')
# (7130, 10411, 961211, 123408, 24, 5142.0, 'A')
# (6818, 9030, 961212, 155616, 48, 3242.0, 'C')
# (5625, 3189, 961215, 222180, 60, 3703.0, 'D')
# (6805, 8972, 961221, 45024, 48, 938.0, 'C')
# (7233, 10963, 961225, 115812, 36, 3217.0, 'C')
# (7308, 11362, 961227, 129408, 24, 5392.0, 'A')
# (5895, 4473, 970103, 93960, 60, 1566.0, 'C')
# (7122, 10365, 970104, 260640, 36, 7240.0, 'D')
# (6173, 5724, 970108, 232560, 48, 4845.0, 'C')
# (6142, 5591, 970121, 221880, 60, 3698.0, 'C')
# (5358, 2018, 970121, 38520, 12, 3210.0, 'A')
# (6095, 5358, 970124, 68340, 60, 1139.0, 'C')
# (6878, 9242, 970124, 23184, 12, 1932.0, 'A')
# (6554, 7637, 970129, 390096, 48, 8127.0, 'C')
# (6793, 8931, 970130, 186300, 60, 3105.0, 'C')
# (7286, 11271, 970131, 67320, 36, 1870.0, 'C')
# (6076, 5269, 970202, 117420, 60, 1957.0, 'C')
# (5134, 825, 970202, 53076, 12, 4423.0, 'A')
# (5419, 2246, 970205, 415800, 60, 6930.0, 'C')
# (6255, 6158, 970208, 247920, 48, 5165.0, 'D')
# (5656, 3353, 970209, 146064, 24, 6086.0, 'C')
# (6934, 9494, 970209, 116832, 12, 9736.0, 'A')
# (6028, 5072, 970209, 317520, 60, 5292.0, 'C')
# (6490, 7262, 970210, 73260, 60, 1221.0, 'C')
# (6415, 6950, 970212, 475680, 48, 9910.0, 'C')
# (7087, 10215, 970220, 44304, 24, 1846.0, 'C')
# (5420, 2247, 970224, 72504, 24, 3021.0, 'C')
# (5977, 4803, 970225, 59136, 48, 1232.0, 'C')
# (6824, 9052, 970226, 71976, 24, 2999.0, 'D')
# (5207, 1244, 970228, 35904, 48, 748.0, 'C')
# (7115, 10351, 970304, 88704, 48, 1848.0, 'C')
# (7250, 11069, 970304, 119136, 48, 2482.0, 'C')
# (6010, 4969, 970306, 150180, 60, 2503.0, 'C')
# (6088, 5317, 970307, 90180, 36, 2505.0, 'C')
# (5682, 3455, 970307, 67464, 12, 5622.0, 'A')
# (7201, 10807, 970307, 67464, 12, 5622.0, 'A')
# (6938, 9504, 970310, 341280, 60, 5688.0, 'C')
# (6875, 9235, 970313, 83280, 48, 1735.0, 'C')
# (5953, 4715, 970314, 97176, 24, 4049.0, 'C')
# (5942, 4681, 970315, 162624, 48, 3388.0, 'C')
# (5382, 2134, 970317, 22932, 36, 637.0, 'C')
# (6377, 6792, 970317, 17184, 12, 1432.0, 'A')
# (5931, 4618, 970317, 66696, 24, 2779.0, 'D')
# (5992, 4863, 970318, 76080, 12, 6340.0, 'A')
# (5790, 4033, 970320, 84288, 48, 1756.0, 'C')
# (6753, 8688, 970320, 67980, 12, 5665.0, 'A')
# (6562, 7674, 970321, 94488, 24, 3937.0, 'C')
# (7046, 10049, 970328, 91632, 12, 7636.0, 'A')
# (5868, 4361, 970329, 90156, 12, 7513.0, 'A')
# (5784, 3967, 970329, 84600, 36, 2350.0, 'D')
# (5878, 4415, 970401, 74040, 12, 6170.0, 'A')
# (5110, 675, 970401, 102240, 60, 1704.0, 'C')
# (5210, 1252, 970401, 148140, 36, 4115.0, 'C')
# (7230, 10954, 970402, 18720, 60, 312.0, 'C')
# (5005, 176, 970410, 27456, 12, 2288.0, 'A')
# (6871, 9225, 970413, 164256, 48, 3422.0, 'C')
# (5363, 2051, 970422, 293880, 60, 4898.0, 'D')
# (7253, 11079, 970426, 98304, 12, 8192.0, 'A')
# (6055, 5181, 970428, 399120, 60, 6652.0, 'C')
# (5072, 472, 970428, 196800, 24, 8200.0, 'D')
# (6913, 9377, 970429, 99936, 24, 4164.0, 'C')
# (6386, 6856, 970430, 124344, 36, 3454.0, 'C')
# (5634, 3229, 970501, 39024, 12, 3252.0, 'A')
# (5758, 3859, 970502, 307200, 60, 5120.0, 'D')
# (6819, 9031, 970503, 50112, 24, 2088.0, 'C')
# (7088, 10233, 970503, 239160, 60, 3986.0, 'C')
# (5039, 314, 970503, 66840, 24, 2785.0, 'C')
# (5532, 2754, 970504, 335280, 48, 6985.0, 'C')
# (6037, 5118, 970504, 53232, 48, 1109.0, 'C')
# (6322, 6510, 970506, 76992, 24, 3208.0, 'C')
# (6887, 9263, 970508, 39576, 12, 3298.0, 'A')
# (6660, 8094, 970509, 220428, 36, 6123.0, 'C')
# (5451, 2350, 970511, 159744, 48, 3328.0, 'C')
# (6014, 4999, 970518, 165168, 36, 4588.0, 'C')
# (5556, 2872, 970519, 268320, 60, 4472.0, 'C')
# (6346, 6649, 970522, 100260, 60, 1671.0, 'C')
# (5850, 4293, 970522, 164196, 36, 4561.0, 'C')
# (5940, 4660, 970528, 106944, 24, 4456.0, 'C')
# (7119, 10361, 970602, 86880, 12, 7240.0, 'A')
# (5253, 1447, 970603, 100080, 48, 2085.0, 'C')
# (6851, 9138, 970603, 272220, 60, 4537.0, 'D')
# (6695, 8320, 970604, 309660, 60, 5161.0, 'C')
# (6908, 9353, 970608, 188616, 24, 7859.0, 'C')
# (7255, 11096, 970609, 213300, 60, 3555.0, 'C')
# (5674, 3418, 970610, 207264, 48, 4318.0, 'C')
# (6278, 6265, 970610, 87360, 24, 3640.0, 'C')
# (5486, 2516, 970613, 466608, 48, 9721.0, 'C')
# (5174, 1093, 970613, 385104, 48, 8023.0, 'C')
# (6621, 7957, 970614, 42900, 12, 3575.0, 'A')
# (6313, 6461, 970615, 150912, 36, 4192.0, 'C')
# (6435, 7045, 970616, 288720, 48, 6015.0, 'C')
# (6970, 9677, 970617, 31620, 60, 527.0, 'C')
# (6310, 6440, 970617, 34572, 12, 2881.0, 'A')
# (5932, 4626, 970618, 33348, 12, 2779.0, 'A')
# (6877, 9241, 970619, 285240, 60, 4754.0, 'C')
# (6763, 8772, 970619, 88272, 48, 1839.0, 'C')
# (7085, 10202, 970619, 305424, 48, 6363.0, 'C')
# (7049, 10063, 970624, 233424, 36, 6484.0, 'C')
# (6959, 9633, 970630, 59448, 24, 2477.0, 'D')
# (5214, 1270, 970701, 74772, 36, 2077.0, 'C')
# (6350, 6678, 970709, 294384, 48, 6133.0, 'C')
# (5063, 442, 970710, 357840, 48, 7455.0, 'D')
# (5041, 319, 970711, 369000, 60, 6150.0, 'C')
# (5086, 525, 970716, 210384, 48, 4383.0, 'C')
# (6942, 9513, 970716, 18324, 12, 1527.0, 'A')
# (5270, 1528, 970721, 191088, 48, 3981.0, 'C')
# (6705, 8381, 970725, 333648, 48, 6951.0, 'D')
# (7051, 10068, 970728, 77808, 12, 6484.0, 'A')
# (6758, 8742, 970729, 33144, 12, 2762.0, 'A')
# (6249, 6138, 970730, 67608, 24, 2817.0, 'C')
# (5808, 4099, 970731, 41856, 48, 872.0, 'C')
# (5377, 2116, 970804, 92400, 12, 7700.0, 'A')
# (5446, 2334, 970804, 48312, 24, 2013.0, 'C')
# (5856, 4320, 970809, 51360, 12, 4280.0, 'B')
# (4986, 97, 970810, 102876, 12, 8573.0, 'A')
# (7001, 9859, 970810, 300600, 60, 5010.0, 'C')
# (6677, 8169, 970812, 97980, 60, 1633.0, 'C')
# (6665, 8114, 970815, 99300, 60, 1655.0, 'C')
# (5817, 4127, 970815, 100800, 24, 4200.0, 'D')
# (6984, 9730, 970815, 116040, 60, 1934.0, 'C')
# (6541, 7565, 970817, 153504, 48, 3198.0, 'C')
# (5117, 718, 970820, 76944, 12, 6412.0, 'A')
# (6097, 5362, 970821, 202848, 48, 4226.0, 'C')
# (5389, 2165, 970822, 78600, 24, 3275.0, 'C')
# (7219, 10905, 970823, 57120, 48, 1190.0, 'C')
# (6338, 6592, 970824, 390660, 60, 6511.0, 'C')
# (6922, 9424, 970826, 83628, 36, 2323.0, 'C')
# (5367, 2064, 970826, 83628, 36, 2323.0, 'C')
# (5638, 3249, 970827, 68124, 12, 5677.0, 'A')
# (5830, 4190, 970828, 405780, 60, 6763.0, 'C')
# (5338, 1888, 970830, 57360, 12, 4780.0, 'B')
# (6007, 4949, 970830, 289920, 48, 6040.0, 'C')
# (6612, 7907, 970831, 97392, 12, 8116.0, 'A')
# (5718, 3637, 970901, 14028, 12, 1169.0, 'A')
# (6104, 5395, 970905, 158184, 36, 4394.0, 'C')
# (5229, 1329, 970906, 23520, 12, 1960.0, 'A')
# (6625, 7966, 970907, 473280, 60, 7888.0, 'D')
# (5206, 1242, 970907, 128544, 24, 5356.0, 'C')
# (5963, 4746, 970907, 204780, 60, 3413.0, 'C')
# (4990, 110, 970908, 162576, 36, 4516.0, 'C')
# (6641, 8026, 970909, 128268, 36, 3563.0, 'C')
# (5369, 2080, 970912, 214596, 36, 5961.0, 'C')
# (6196, 5837, 970914, 177804, 36, 4939.0, 'C')
# (5236, 1374, 970915, 389136, 48, 8107.0, 'C')
# (5719, 3664, 970920, 271584, 48, 5658.0, 'C')
# (5643, 3273, 970921, 94512, 12, 7876.0, 'B')
# (7050, 10065, 970923, 311232, 48, 6484.0, 'C')
# (6355, 6699, 970924, 127200, 48, 2650.0, 'C')
# (6688, 8268, 970926, 8616, 24, 359.0, 'C')
# (6239, 6083, 970928, 360864, 48, 7518.0, 'D')
# (5531, 2753, 970930, 66432, 24, 2768.0, 'C')
# (6113, 5445, 971001, 78696, 36, 2186.0, 'C')
# (7181, 10679, 971002, 197808, 24, 8242.0, 'C')
# (6118, 5477, 971004, 349392, 48, 7279.0, 'C')
# (7264, 11141, 971007, 44940, 12, 3745.0, 'A')
# (5343, 1906, 971008, 44952, 24, 1873.0, 'C')
# (5051, 378, 971011, 230400, 60, 3840.0, 'C')
# (5779, 3942, 971014, 107352, 36, 2982.0, 'C')
# (6605, 7890, 971014, 79344, 48, 1653.0, 'C')
# (6655, 8085, 971017, 260400, 60, 4340.0, 'D')
# (6534, 7542, 971019, 590820, 60, 9847.0, 'C')
# (5681, 3448, 971020, 68664, 24, 2861.0, 'C')
# (6607, 7894, 971021, 153144, 36, 4254.0, 'C')
# (6242, 6097, 971022, 26208, 36, 728.0, 'C')
# (7242, 11027, 971023, 48096, 24, 2004.0, 'C')
# (7277, 11231, 971024, 89280, 12, 7440.0, 'A')
# (6675, 8158, 971101, 238716, 36, 6631.0, 'C')
# (5398, 2187, 971104, 53472, 12, 4456.0, 'A')
# (5956, 4725, 971104, 168264, 36, 4674.0, 'C')
# (5731, 3711, 971105, 460980, 60, 7683.0, 'D')
# (6956, 9631, 971109, 59448, 24, 2477.0, 'C')
# (6437, 7052, 971109, 63972, 36, 1777.0, 'D')
# (5447, 2335, 971112, 541200, 60, 9020.0, 'D')
# (5973, 4784, 971124, 219456, 48, 4572.0, 'C')
# (6075, 5267, 971126, 129312, 24, 5388.0, 'D')
# (5281, 1580, 971127, 194256, 24, 8094.0, 'C')
# (5103, 666, 971128, 12540, 12, 1045.0, 'A')
# (6468, 7176, 971130, 203940, 60, 3399.0, 'C')
# (7209, 10857, 971130, 385560, 60, 6426.0, 'D')
# (5584, 2986, 971206, 24792, 24, 1033.0, 'C')
# (4988, 103, 971206, 265320, 36, 7370.0, 'D')
# (6502, 7424, 971208, 30276, 12, 2523.0, 'A')
# (5651, 3329, 971208, 19248, 12, 1604.0, 'A')
# (4962, 25, 971208, 30276, 12, 2523.0, 'A')
# (5862, 4342, 971209, 100128, 24, 4172.0, 'C')
# (7199, 10789, 971209, 45768, 12, 3814.0, 'A')
# (6727, 8505, 971210, 42840, 12, 3570.0, 'A')
# (7279, 11244, 971211, 155760, 24, 6490.0, 'C')
# (6544, 7594, 971211, 130464, 48, 2718.0, 'C')
# (5933, 4631, 971213, 87528, 24, 3647.0, 'C')
# (6574, 7745, 971220, 77544, 36, 2154.0, 'C')
# (6399, 6902, 971221, 49320, 36, 1370.0, 'C')
# (7187, 10711, 971224, 24180, 60, 403.0, 'C')
# (6353, 6686, 971225, 116496, 24, 4854.0, 'C')
# (5043, 339, 971225, 468060, 60, 7801.0, 'C')
# (5469, 2445, 971226, 293160, 60, 4886.0, 'C')
# (5976, 4794, 971227, 465504, 48, 9698.0, 'D')
# (6059, 5196, 971228, 79824, 12, 6652.0, 'A')
# (5799, 4052, 971228, 106128, 36, 2948.0, 'C')
# (6147, 5602, 971228, 177504, 48, 3698.0, 'C')
# (6254, 6157, 971228, 247920, 48, 5165.0, 'C')
# (7100, 10280, 971231, 348120, 60, 5802.0, 'C')
# (7147, 10478, 980102, 267600, 48, 5575.0, 'C')
# (5909, 4550, 980103, 61320, 60, 1022.0, 'C')
# (7037, 10022, 980103, 218064, 48, 4543.0, 'C')
# (5782, 3953, 980104, 63576, 12, 5298.0, 'C')
# (6237, 6075, 980106, 407952, 48, 8499.0, 'D')
# (6552, 7632, 980108, 170448, 48, 3551.0, 'C')
# (7067, 10134, 980111, 136368, 24, 5682.0, 'C')
# (5320, 1819, 980111, 143676, 36, 3991.0, 'C')
# (5930, 4616, 980112, 66696, 24, 2779.0, 'C')
# (6486, 7240, 980115, 152160, 60, 2536.0, 'C')
# (5245, 1407, 980117, 125472, 24, 5228.0, 'C')
# (6643, 8038, 980118, 35856, 24, 1494.0, 'C')
# (5260, 1480, 980119, 123300, 36, 3425.0, 'C')
# (5569, 2936, 980120, 504000, 60, 8400.0, 'C')
# (7110, 10345, 980121, 31260, 12, 2605.0, 'C')
# (7139, 10445, 980122, 23412, 12, 1951.0, 'C')
# (6791, 8926, 980123, 566640, 60, 9444.0, 'C')
# (5360, 2035, 980125, 176328, 36, 4898.0, 'C')
# (5287, 1638, 980126, 64224, 24, 2676.0, 'C')
# (6553, 7636, 980126, 42384, 12, 3532.0, 'C')
# (7072, 10148, 980127, 22104, 12, 1842.0, 'C')
# (6044, 5133, 980127, 57060, 12, 4755.0, 'C')
# (5332, 1869, 980129, 37944, 36, 1054.0, 'C')
# (6866, 9201, 980205, 122472, 24, 5103.0, 'C')
# (6633, 7997, 980205, 160656, 24, 6694.0, 'C')
# (6926, 9455, 980207, 374760, 60, 6246.0, 'C')
# (6442, 7082, 980208, 194160, 48, 4045.0, 'C')
# (5889, 4456, 980209, 321240, 60, 5354.0, 'C')
# (5765, 3875, 980210, 153936, 24, 6414.0, 'C')
# (5124, 785, 980212, 156096, 36, 4336.0, 'C')
# (5491, 2545, 980213, 428784, 48, 8933.0, 'C')
# (6730, 8523, 980215, 93036, 12, 7753.0, 'C')
# (7151, 10493, 980218, 133800, 24, 5575.0, 'C')
# (5140, 873, 980224, 178500, 60, 2975.0, 'C')
# (7171, 10650, 980224, 196224, 48, 4088.0, 'C')
# (6568, 7713, 980225, 220440, 60, 3674.0, 'C')
# (6861, 9179, 980228, 215040, 60, 3584.0, 'C')
# (6855, 9153, 980301, 52236, 36, 1451.0, 'C')
# (7129, 10404, 980301, 194280, 60, 3238.0, 'C')
# (5384, 2142, 980307, 23328, 12, 1944.0, 'C')
# (6859, 9167, 980307, 272220, 60, 4537.0, 'C')
# (5772, 3906, 980308, 334620, 60, 5577.0, 'C')
# (5665, 3390, 980311, 40632, 12, 3386.0, 'C')
# (6495, 7274, 980312, 49044, 12, 4087.0, 'C')
# (5061, 440, 980313, 84288, 48, 1756.0, 'C')
# (6948, 9560, 980315, 157068, 36, 4363.0, 'C')
# (5773, 3907, 980316, 133848, 24, 5577.0, 'C')
# (6052, 5164, 980323, 22356, 36, 621.0, 'C')
# (6682, 8225, 980330, 36204, 12, 3017.0, 'D')
# (6083, 5305, 980331, 240528, 48, 5011.0, 'C')
# (6962, 9646, 980402, 279072, 48, 5814.0, 'C')
# (5158, 1004, 980411, 188532, 36, 5237.0, 'C')
# (6464, 7156, 980416, 49488, 24, 2062.0, 'C')
# (5172, 1083, 980416, 50976, 36, 1416.0, 'C')
# (5582, 2982, 980417, 41256, 12, 3438.0, 'C')
# (6136, 5572, 980419, 140880, 60, 2348.0, 'C')
# (6235, 6062, 980419, 321360, 60, 5356.0, 'C')
# (6508, 7437, 980419, 110736, 48, 2307.0, 'C')
# (4968, 38, 980419, 110736, 48, 2307.0, 'C')
# (6632, 7990, 980423, 144960, 48, 3020.0, 'C')
# (7195, 10774, 980423, 339168, 48, 7066.0, 'C')
# (5525, 2720, 980427, 93888, 36, 2608.0, 'C')
# (6320, 6495, 980428, 104964, 12, 8747.0, 'C')
# (6766, 8784, 980428, 74352, 24, 3098.0, 'C')
# (6872, 9227, 980429, 191580, 60, 3193.0, 'C')
# (5906, 4533, 980505, 81144, 36, 2254.0, 'C')
# (7172, 10652, 980507, 45720, 12, 3810.0, 'C')
# (6571, 7733, 980512, 140064, 24, 5836.0, 'C')
# (5616, 3143, 980515, 130896, 24, 5454.0, 'C')
# (6312, 6453, 980517, 10944, 36, 304.0, 'C')
# (6470, 7181, 980517, 49872, 12, 4156.0, 'C')
# (5147, 938, 980521, 22260, 60, 371.0, 'C')
# (5501, 2622, 980521, 136344, 24, 5681.0, 'C')
# (6436, 7049, 980522, 495180, 60, 8253.0, 'C')
# (5699, 3562, 980524, 174960, 24, 7290.0, 'C')
# (5313, 1776, 980527, 43200, 24, 1800.0, 'C')
# (6234, 6061, 980528, 5148, 12, 429.0, 'C')
# (6569, 7721, 980528, 45456, 12, 3788.0, 'C')
# (7202, 10812, 980529, 140688, 48, 2931.0, 'C')
# (5683, 3460, 980529, 140688, 48, 2931.0, 'C')
# (5034, 303, 980530, 112752, 36, 3132.0, 'C')
# (5435, 2279, 980601, 314688, 48, 6556.0, 'C')
# (5815, 4116, 980603, 151200, 36, 4200.0, 'C')
# (5589, 3005, 980605, 390000, 48, 8125.0, 'C')
# (6746, 8639, 980606, 185640, 60, 3094.0, 'C')
# (6790, 8919, 980608, 76104, 24, 3171.0, 'C')
# (6857, 9159, 980608, 69600, 48, 1450.0, 'C')
# (6450, 7099, 980610, 234336, 48, 4882.0, 'C')
# (7221, 10915, 980611, 152460, 60, 2541.0, 'C')
# (5527, 2728, 980615, 156420, 60, 2607.0, 'C')
# (5620, 3161, 980616, 30012, 12, 2501.0, 'C')
# (6215, 5944, 980618, 78720, 48, 1640.0, 'C')
# (7167, 10644, 980618, 269964, 36, 7499.0, 'C')
# (5823, 4144, 980621, 212976, 36, 5916.0, 'C')
# (6207, 5912, 980623, 184620, 60, 3077.0, 'C')
# (6932, 9491, 980625, 225504, 48, 4698.0, 'C')
# (5669, 3403, 980627, 71820, 36, 1995.0, 'C')
# (5154, 993, 980701, 108720, 60, 1812.0, 'C')
# (7168, 10645, 980705, 208332, 36, 5787.0, 'C')
# (5585, 2988, 980708, 88608, 12, 7384.0, 'C')
# (7200, 10799, 980711, 31140, 60, 519.0, 'C')
# (6539, 7559, 980711, 12792, 12, 1066.0, 'C')
# (5774, 3916, 980712, 96984, 36, 2694.0, 'C')
# (6357, 6706, 980712, 64860, 60, 1081.0, 'C')
# (5042, 330, 980712, 331584, 48, 6908.0, 'C')
# (5015, 226, 980712, 109344, 12, 9112.0, 'C')
# (5354, 2000, 980714, 290820, 60, 4847.0, 'C')
# (6054, 5180, 980716, 58764, 12, 4897.0, 'C')
# (7295, 11328, 980718, 280440, 60, 4674.0, 'C')
# (5365, 2055, 980719, 271260, 60, 4521.0, 'C')
# (6755, 8713, 980724, 170700, 60, 2845.0, 'C')
# (5991, 4858, 980727, 335184, 48, 6983.0, 'D')
# (7035, 10005, 980729, 210744, 36, 5854.0, 'C')
# (5893, 4467, 980803, 86184, 36, 2394.0, 'C')
# (7164, 10613, 980815, 249792, 48, 5204.0, 'C')
# (5304, 1718, 980820, 172272, 24, 7178.0, 'C')
# (5561, 2910, 980829, 437460, 60, 7291.0, 'C')
# (5520, 2699, 980830, 231168, 48, 4816.0, 'C')
# (5241, 1389, 980902, 125472, 24, 5228.0, 'C')
# (7096, 10257, 980902, 37812, 12, 3151.0, 'C')
# (6078, 5283, 980909, 170832, 48, 3559.0, 'C')
# (5046, 349, 980909, 42816, 12, 3568.0, 'C')
# (5334, 1876, 980910, 209040, 24, 8710.0, 'C')
# (6969, 9673, 980912, 88200, 36, 2450.0, 'C')
# (6821, 9037, 980915, 321936, 48, 6707.0, 'C')
# (5760, 3862, 980918, 74916, 36, 2081.0, 'C')
# (5614, 3137, 980921, 253560, 60, 4226.0, 'C')
# (7091, 10243, 980922, 113436, 36, 3151.0, 'C')
# (5698, 3556, 980922, 174840, 60, 2914.0, 'C')
# (5169, 1068, 980924, 253200, 60, 4220.0, 'C')
# (7294, 11327, 980927, 39168, 24, 1632.0, 'C')
# (5318, 1808, 980930, 385584, 48, 8033.0, 'C')
# (5368, 2073, 981005, 44640, 24, 1860.0, 'C')
# (6923, 9433, 981005, 44640, 24, 1860.0, 'C')
# (5463, 2413, 981006, 17952, 12, 1496.0, 'C')
# (5265, 1498, 981007, 165780, 60, 2763.0, 'C')
# (6321, 6505, 981008, 38496, 12, 3208.0, 'C')
# (5226, 1318, 981011, 185544, 36, 5154.0, 'C')
# (6868, 9208, 981012, 82128, 24, 3422.0, 'C')
# (4967, 37, 981014, 318480, 60, 5308.0, 'D')
# (5293, 1656, 981029, 189792, 48, 3954.0, 'C')
# (5865, 4354, 981030, 327660, 60, 5461.0, 'C')
# (5841, 4268, 981104, 41988, 12, 3499.0, 'C')
# (5526, 2725, 981108, 69624, 36, 1934.0, 'C')
# (6852, 9140, 981110, 16032, 48, 334.0, 'C')
# (6469, 7180, 981117, 99744, 24, 4156.0, 'C')
# (6168, 5698, 981121, 99216, 36, 2756.0, 'C')
# (7292, 11317, 981122, 317460, 60, 5291.0, 'C')
# (5036, 309, 981125, 91248, 48, 1901.0, 'C')
# (5644, 3293, 981127, 276084, 36, 7669.0, 'C')
# (6856, 9156, 981201, 163332, 36, 4537.0, 'C')
# (5428, 2262, 981202, 230220, 36, 6395.0, 'C')
# (5027, 276, 981202, 160920, 36, 4470.0, 'C')
# (4989, 105, 981205, 352704, 48, 7348.0, 'C')
# (5221, 1284, 981205, 52512, 12, 4376.0, 'C')
# (6402, 6922, 981206, 139488, 24, 5812.0, 'C')
# (5346, 1928, 981206, 55632, 24, 2318.0, 'C')
# (6748, 8645, 981208, 240900, 60, 4015.0, 'C')

# %%
# We can also use the method fetchall() to get all those tuples in a list

with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    print(result.fetchall())
# Out:
# [(5314, 1787, 930705, 96396, 12, 8033.0, 'B'), (5316, 1801, 930711, 165960, 36, 4610.0, 'A'), (6863, 9188, 930728, 127080, 60, 2118.0, 'A'), (5325, 1843, 930803, 105804, 36, 2939.0, 'A'), (7240, 11013, 930906, 274740, 60, 4579.0, 'A'), (6687, 8261, 930913, 87840, 24, 3660.0, 'A'), (7284, 11265, 930915, 52788, 12, 4399.0, 'A'), (6111, 5428, 930924, 174744, 24, 7281.0, 'B'), (7235, 10973, 931013, 154416, 48, 3217.0, 'A'), (5997, 4894, 931104, 117024, 24, 4876.0, 'A'), (7121, 10364, 931110, 21924, 36, 609.0, 'A'), (6077, 5270, 931122, 79608, 24, 3317.0, 'A'), (6228, 6034, 931201, 464520, 60, 7742.0, 'B'), (6356, 6701, 931208, 95400, 36, 2650.0, 'A'), (5523, 2705, 931208, 93888, 36, 2608.0, 'A'), (6456, 7123, 931209, 47016, 12, 3918.0, 'A'), (7104, 10320, 931213, 259740, 60, 4329.0, 'A'), (6820, 9034, 931216, 38148, 12, 3179.0, 'A'), (6876, 9236, 931221, 86616, 12, 7218.0, 'A'), (7097, 10266, 931223, 75624, 24, 3151.0, 'B'), (4959, 2, 940105, 80952, 24, 3373.0, 'A'), (6499, 7401, 940105, 80952, 24, 3373.0, 'A'), (5479, 2486, 940110, 24516, 12, 2043.0, 'A'), (5170, 1071, 940120, 253200, 60, 4220.0, 'C'), (6721, 8475, 940121, 21072, 24, 878.0, 'A'), (7259, 11111, 940131, 108144, 36, 3004.0, 'A'), (5285, 1603, 940206, 78936, 12, 6578.0, 'A'), (5189, 1166, 940207, 149040, 48, 3105.0, 'A'), (6650, 8073, 940217, 49320, 12, 4110.0, 'B'), (7226, 10940, 940223, 197748, 36, 5493.0, 'A'), (6087, 5313, 940227, 300660, 60, 5011.0, 'C'), (7262, 11135, 940301, 182628, 36, 5073.0, 'A'), (5519, 2694, 940308, 91632, 12, 7636.0, 'A'), (6577, 7753, 940311, 51696, 24, 2154.0, 'A'), (6509, 7445, 940315, 55368, 24, 2307.0, 'A'), (6520, 7485, 940316, 91200, 24, 3800.0, 'A'), (6699, 8330, 940330, 7656, 24, 319.0, 'A'), (6336, 6555, 940331, 212400, 36, 5900.0, 'A'), (7055, 10079, 940406, 167100, 60, 2785.0, 'C'), (6103, 5385, 940407, 149340, 60, 2489.0, 'C'), (6202, 5891, 940418, 65184, 12, 5432.0, 'A'), (7066, 10131, 940502, 215388, 36, 5983.0, 'B'), (6696, 8321, 940509, 89040, 60, 1484.0, 'C'), (6072, 5256, 940510, 193968, 36, 5388.0, 'A'), (5130, 813, 940511, 24312, 12, 2026.0, 'A'), (5568, 2933, 940517, 272520, 60, 4542.0, 'C'), (6678, 8173, 940520, 80340, 12, 6695.0, 'A'), (6998, 9833, 940521, 97632, 12, 8136.0, 'A'), (6580, 7769, 940522, 196080, 48, 4085.0, 'A'), (6316, 6473, 940526, 76908, 12, 6409.0, 'B'), (6512, 7454, 940526, 63312, 48, 1319.0, 'A'), (6407, 6930, 940526, 25944, 24, 1081.0, 'A'), (5002, 173, 940531, 104808, 12, 8734.0, 'A'), (6647, 8051, 940601, 208320, 48, 4340.0, 'A'), (7137, 10439, 940603, 151560, 24, 6315.0, 'A'), (6903, 9337, 940604, 52128, 24, 2172.0, 'A'), (5918, 4576, 940604, 300204, 36, 8339.0, 'A'), (6642, 8027, 940605, 77640, 12, 6470.0, 'A'), (6210, 5927, 940606, 87216, 48, 1817.0, 'B'), (6279, 6273, 940607, 87360, 24, 3640.0, 'A'), (7249, 11065, 940612, 69360, 48, 1445.0, 'A'), (6736, 8558, 940614, 288360, 60, 4806.0, 'C'), (6112, 5442, 940617, 174744, 24, 7281.0, 'B'), (5319, 1811, 940623, 239460, 60, 3991.0, 'C'), (6596, 7844, 940625, 91584, 24, 3816.0, 'A'), (5837, 4260, 940629, 244560, 60, 4076.0, 'C'), (5657, 3354, 940705, 4980, 12, 415.0, 'A'), (5533, 2762, 940705, 111384, 24, 4641.0, 'A'), (6232, 6051, 940708, 276660, 36, 7685.0, 'B'), (6888, 9265, 940711, 39576, 12, 3298.0, 'A'), (6066, 5228, 940711, 173808, 24, 7242.0, 'A'), (5549, 2824, 940716, 50460, 60, 841.0, 'C'), (5060, 426, 940719, 252060, 60, 4201.0, 'D'), (6004, 4937, 940723, 143904, 24, 5996.0, 'A'), (5126, 790, 940724, 208128, 48, 4336.0, 'B'), (7220, 10911, 940728, 131292, 36, 3647.0, 'A'), (6668, 8129, 940730, 74736, 36, 2076.0, 'A'), (5395, 2176, 940730, 299088, 36, 8308.0, 'B'), (6836, 9093, 940803, 189300, 60, 3155.0, 'C'), (6064, 5215, 940804, 14628, 12, 1219.0, 'A'), (6919, 9403, 940805, 120888, 36, 3358.0, 'A'), (6841, 9104, 940807, 172080, 48, 3585.0, 'A'), (6038, 5120, 940810, 323472, 48, 6739.0, 'A'), (6729, 8519, 940811, 74688, 12, 6224.0, 'A'), (7198, 10788, 940823, 45768, 12, 3814.0, 'A'), (6686, 8260, 940825, 224604, 36, 6239.0, 'A'), ...

# %%
# Instead of fetchall() we can get the same result using all(). This code has the same outcome as the block above

with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    print(result.all())
# Out:
# [(5314, 1787, 930705, 96396, 12, 8033.0, 'B'), (5316, 1801, 930711, 165960, 36, 4610.0, 'A'), (6863, 9188, 930728, 127080, 60, 2118.0, 'A'), (5325, 1843, 930803, 105804, 36, 2939.0, 'A'), (7240, 11013, 930906, 274740, 60, 4579.0, 'A'), (6687, 8261, 930913, 87840, 24, 3660.0, 'A'), (7284, 11265, 930915, 52788, 12, 4399.0, 'A'), (6111, 5428, 930924, 174744, 24, 7281.0, 'B'), (7235, 10973, 931013, 154416, 48, 3217.0, 'A'), (5997, 4894, 931104, 117024, 24, 4876.0, 'A'), (7121, 10364, 931110, 21924, 36, 609.0, 'A'), (6077, 5270, 931122, 79608, 24, 3317.0, 'A'), (6228, 6034, 931201, 464520, 60, 7742.0, 'B'), (6356, 6701, 931208, 95400, 36, 2650.0, 'A'), (5523, 2705, 931208, 93888, 36, 2608.0, 'A'), (6456, 7123, 931209, 47016, 12, 3918.0, 'A'), (7104, 10320, 931213, 259740, 60, 4329.0, 'A'), (6820, 9034, 931216, 38148, 12, 3179.0, 'A'), (6876, 9236, 931221, 86616, 12, 7218.0, 'A'), (7097, 10266, 931223, 75624, 24, 3151.0, 'B'), (4959, 2, 940105, 80952, 24, 3373.0, 'A'), (6499, 7401, 940105, 80952, 24, 3373.0, 'A'), (5479, 2486, 940110, 24516, 12, 2043.0, 'A'), (5170, 1071, 940120, 253200, 60, 4220.0, 'C'), (6721, 8475, 940121, 21072, 24, 878.0, 'A'), (7259, 11111, 940131, 108144, 36, 3004.0, 'A'), (5285, 1603, 940206, 78936, 12, 6578.0, 'A'), (5189, 1166, 940207, 149040, 48, 3105.0, 'A'), (6650, 8073, 940217, 49320, 12, 4110.0, 'B'), (7226, 10940, 940223, 197748, 36, 5493.0, 'A'), (6087, 5313, 940227, 300660, 60, 5011.0, 'C'), (7262, 11135, 940301, 182628, 36, 5073.0, 'A'), (5519, 2694, 940308, 91632, 12, 7636.0, 'A'), (6577, 7753, 940311, 51696, 24, 2154.0, 'A'), (6509, 7445, 940315, 55368, 24, 2307.0, 'A'), (6520, 7485, 940316, 91200, 24, 3800.0, 'A'), (6699, 8330, 940330, 7656, 24, 319.0, 'A'), (6336, 6555, 940331, 212400, 36, 5900.0, 'A'), (7055, 10079, 940406, 167100, 60, 2785.0, 'C'), (6103, 5385, 940407, 149340, 60, 2489.0, 'C'), (6202, 5891, 940418, 65184, 12, 5432.0, 'A'), (7066, 10131, 940502, 215388, 36, 5983.0, 'B'), (6696, 8321, 940509, 89040, 60, 1484.0, 'C'), (6072, 5256, 940510, 193968, 36, 5388.0, 'A'), (5130, 813, 940511, 24312, 12, 2026.0, 'A'), (5568, 2933, 940517, 272520, 60, 4542.0, 'C'), (6678, 8173, 940520, 80340, 12, 6695.0, 'A'), (6998, 9833, 940521, 97632, 12, 8136.0, 'A'), (6580, 7769, 940522, 196080, 48, 4085.0, 'A'), (6316, 6473, 940526, 76908, 12, 6409.0, 'B'), (6512, 7454, 940526, 63312, 48, 1319.0, 'A'), (6407, 6930, 940526, 25944, 24, 1081.0, 'A'), (5002, 173, 940531, 104808, 12, 8734.0, 'A'), (6647, 8051, 940601, 208320, 48, 4340.0, 'A'), (7137, 10439, 940603, 151560, 24, 6315.0, 'A'), (6903, 9337, 940604, 52128, 24, 2172.0, 'A'), (5918, 4576, 940604, 300204, 36, 8339.0, 'A'), (6642, 8027, 940605, 77640, 12, 6470.0, 'A'), (6210, 5927, 940606, 87216, 48, 1817.0, 'B'), (6279, 6273, 940607, 87360, 24, 3640.0, 'A'), (7249, 11065, 940612, 69360, 48, 1445.0, 'A'), (6736, 8558, 940614, 288360, 60, 4806.0, 'C'), (6112, 5442, 940617, 174744, 24, 7281.0, 'B'), (5319, 1811, 940623, 239460, 60, 3991.0, 'C'), (6596, 7844, 940625, 91584, 24, 3816.0, 'A'), (5837, 4260, 940629, 244560, 60, 4076.0, 'C'), (5657, 3354, 940705, 4980, 12, 415.0, 'A'), (5533, 2762, 940705, 111384, 24, 4641.0, 'A'), (6232, 6051, 940708, 276660, 36, 7685.0, 'B'), (6888, 9265, 940711, 39576, 12, 3298.0, 'A'), (6066, 5228, 940711, 173808, 24, 7242.0, 'A'), (5549, 2824, 940716, 50460, 60, 841.0, 'C'), (5060, 426, 940719, 252060, 60, 4201.0, 'D'), (6004, 4937, 940723, 143904, 24, 5996.0, 'A'), (5126, 790, 940724, 208128, 48, 4336.0, 'B'), (7220, 10911, 940728, 131292, 36, 3647.0, 'A'), (6668, 8129, 940730, 74736, 36, 2076.0, 'A'), (5395, 2176, 940730, 299088, 36, 8308.0, 'B'), (6836, 9093, 940803, 189300, 60, 3155.0, 'C'), (6064, 5215, 940804, 14628, 12, 1219.0, 'A'), (6919, 9403, 940805, 120888, 36, 3358.0, 'A'), (6841, 9104, 940807, 172080, 48, 3585.0, 'A'), (6038, 5120, 940810, 323472, 48, 6739.0, 'A'), (6729, 8519, 940811, 74688, 12, 6224.0, 'A'), (7198, 10788, 940823, 45768, 12, 3814.0, 'A'), (6686, 8260, 940825, 224604, 36, 6239.0, 'A'), ...

# %%
# We can also get it as a DataFrame

with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    df = pd.DataFrame(result.all())

df
# Out:
#      loan_id  account_id    date  amount  duration  payments status
# 0       5314        1787  930705   96396        12    8033.0      B
# 1       5316        1801  930711  165960        36    4610.0      A
# 2       6863        9188  930728  127080        60    2118.0      A
# 3       5325        1843  930803  105804        36    2939.0      A
# 4       7240       11013  930906  274740        60    4579.0      A
# ..       ...         ...     ...     ...       ...       ...    ...
# 677     4989         105  981205  352704        48    7348.0      C
# 678     5221        1284  981205   52512        12    4376.0      C
# 679     6402        6922  981206  139488        24    5812.0      C
# 680     5346        1928  981206   55632        24    2318.0      C
# 681     6748        8645  981208  240900        60    4015.0      C
#
# [682 rows x 7 columns]

# %% [markdown]
# #### Iterate through the first column

# %% [markdown]
# We can use the method `.scalars()` which gives a `ScalarResult`.

# %%
with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    for id in result.scalars():
        print(id)
# Out:
# 5314
# 5316
# 6863
# 5325
# 7240
# 6687
# 7284
# 6111
# 7235
# 5997
# 7121
# 6077
# 6228
# 6356
# 5523
# 6456
# 7104
# 6820
# 6876
# 7097
# 4959
# 6499
# 5479
# 5170
# 6721
# 7259
# 5285
# 5189
# 6650
# 7226
# 6087
# 7262
# 5519
# 6577
# 6509
# 6520
# 6699
# 6336
# 7055
# 6103
# 6202
# 7066
# 6696
# 6072
# 5130
# 5568
# 6678
# 6998
# 6580
# 6316
# 6512
# 6407
# 5002
# 6647
# 7137
# 6903
# 5918
# 6642
# 6210
# 6279
# 7249
# 6736
# 6112
# 5319
# 6596
# 5837
# 5657
# 5533
# 6232
# 6888
# 6066
# 5549
# 5060
# 6004
# 5126
# 7220
# 6668
# 5395
# 6836
# 6064
# 6919
# 6841
# 6038
# 6729
# 7198
# 6686
# 5836
# 7061
# 5595
# 5723
# 6120
# 6895
# 5882
# 5754
# 6594
# 6738
# 6624
# 6216
# 6229
# 5887
# 6808
# 6297
# 5161
# 5390
# 6150
# 6223
# 5032
# 6253
# 6460
# 6645
# 5176
# 5269
# 5351
# 5861
# 5450
# 7142
# 6306
# 6272
# 5044
# 5576
# 7192
# 5739
# 6526
# 5624
# 6244
# 5131
# 6960
# 6358
# 5418
# 6598
# 5464
# 6591
# 5724
# 6315
# 5876
# 6986
# 6294
# 5132
# 5877
# 6227
# 7241
# 6737
# 7004
# 6169
# 5208
# 6694
# 5599
# 6546
# 5414
# 5453
# 5740
# 5804
# 6745
# 6950
# 6996
# 5352
# 6151
# 5310
# 5045
# 6929
# 5151
# 5212
# 5138
# 5713
# 6704
# 6474
# 6676
# 6965
# 6725
# 7166
# 7138
# 5970
# 6157
# 6153
# 5693
# 5922
# 5959
# 5980
# 6764
# 5237
# 6726
# 6933
# 5145
# 7008
# 7227
# 6600
# 6712
# 7057
# 7176
# 7304
# 6362
# 5880
# 6535
# 5449
# 6342
# 5409
# 6955
# 6985
# 5125
# 5805
# 6185
# 7243
# 6403
# 6578
# 5413
# 6949
# 6545
# 6178
# 5160
# 6785
# 6540
# 6589
# 5900
# 5999
# 6043
# 5482
# 7263
# 6013
# 5750
# 6027
# 6303
# 7213
# 6659
# 6175
# 5610
# 5563
# 5989
# 6698
# 5312
# 7189
# 6816
# 6137
# 5128
# 5470
# 5593
# 5350
# 6063
# 6501
# 5452
# 4961
# 4973
# 6190
# 6715
# 5892
# 6550
# 5706
# 5148
# 6734
# 6109
# 6961
# 6810
# 5494
# 5311
# 5445
# 5301
# 7034
# 6751
# 6667
# 6130
# 5429
# 5725
# 6019
# 6421
# 6992
# 5136
# 5337
# 5495
# 7013
# 6012
# 6471
# 6296
# 7305
# 6144
# 6283
# 7246
# 5088
# 5988
# 5282
# 5938
# 5606
# 5385
# 6865
# 5586
# 6302
# 7194
# 6461
# 6732
# 6613
# 7036
# 5897
# 6995
# 5415
# 7136
# 7271
# 5375
# 5635
# 6817
# 5923
# 5329
# 6644
# 6354
# 5082
# 6585
# 6921
# 5366
# 5886
# 5741
# 4996
# 6015
# 6309
# 6073
# 6006
# 5611
# 6944
# 7101
# 6599
# 6940
# 5209
# 5388
# 6011
# 5591
# 7154
# 7130
# 6818
# 5625
# 6805
# 7233
# 7308
# 5895
# 7122
# 6173
# 6142
# 5358
# 6095
# 6878
# 6554
# 6793
# 7286
# 6076
# 5134
# 5419
# 6255
# 5656
# 6934
# 6028
# 6490
# 6415
# 7087
# 5420
# 5977
# 6824
# 5207
# 7115
# 7250
# 6010
# 6088
# 5682
# 7201
# 6938
# 6875
# 5953
# 5942
# 5382
# 6377
# 5931
# 5992
# 5790
# 6753
# 6562
# 7046
# 5868
# 5784
# 5878
# 5110
# 5210
# 7230
# 5005
# 6871
# 5363
# 7253
# 6055
# 5072
# 6913
# 6386
# 5634
# 5758
# 6819
# 7088
# 5039
# 5532
# 6037
# 6322
# 6887
# 6660
# 5451
# 6014
# 5556
# 6346
# 5850
# 5940
# 7119
# 5253
# 6851
# 6695
# 6908
# 7255
# 5674
# 6278
# 5486
# 5174
# 6621
# 6313
# 6435
# 6970
# 6310
# 5932
# 6877
# 6763
# 7085
# 7049
# 6959
# 5214
# 6350
# 5063
# 5041
# 5086
# 6942
# 5270
# 6705
# 7051
# 6758
# 6249
# 5808
# 5377
# 5446
# 5856
# 4986
# 7001
# 6677
# 6665
# 5817
# 6984
# 6541
# 5117
# 6097
# 5389
# 7219
# 6338
# 6922
# 5367
# 5638
# 5830
# 5338
# 6007
# 6612
# 5718
# 6104
# 5229
# 6625
# 5206
# 5963
# 4990
# 6641
# 5369
# 6196
# 5236
# 5719
# 5643
# 7050
# 6355
# 6688
# 6239
# 5531
# 6113
# 7181
# 6118
# 7264
# 5343
# 5051
# 5779
# 6605
# 6655
# 6534
# 5681
# 6607
# 6242
# 7242
# 7277
# 6675
# 5398
# 5956
# 5731
# 6956
# 6437
# 5447
# 5973
# 6075
# 5281
# 5103
# 6468
# 7209
# 5584
# 4988
# 6502
# 5651
# 4962
# 5862
# 7199
# 6727
# 7279
# 6544
# 5933
# 6574
# 6399
# 7187
# 6353
# 5043
# 5469
# 5976
# 6059
# 5799
# 6147
# 6254
# 7100
# 7147
# 5909
# 7037
# 5782
# 6237
# 6552
# 7067
# 5320
# 5930
# 6486
# 5245
# 6643
# 5260
# 5569
# 7110
# 7139
# 6791
# 5360
# 5287
# 6553
# 7072
# 6044
# 5332
# 6866
# 6633
# 6926
# 6442
# 5889
# 5765
# 5124
# 5491
# 6730
# 7151
# 5140
# 7171
# 6568
# 6861
# 6855
# 7129
# 5384
# 6859
# 5772
# 5665
# 6495
# 5061
# 6948
# 5773
# 6052
# 6682
# 6083
# 6962
# 5158
# 6464
# 5172
# 5582
# 6136
# 6235
# 6508
# 4968
# 6632
# 7195
# 5525
# 6320
# 6766
# 6872
# 5906
# 7172
# 6571
# 5616
# 6312
# 6470
# 5147
# 5501
# 6436
# 5699
# 5313
# 6234
# 6569
# 7202
# 5683
# 5034
# 5435
# 5815
# 5589
# 6746
# 6790
# 6857
# 6450
# 7221
# 5527
# 5620
# 6215
# 7167
# 5823
# 6207
# 6932
# 5669
# 5154
# 7168
# 5585
# 7200
# 6539
# 5774
# 6357
# 5042
# 5015
# 5354
# 6054
# 7295
# 5365
# 6755
# 5991
# 7035
# 5893
# 7164
# 5304
# 5561
# 5520
# 5241
# 7096
# 6078
# 5046
# 5334
# 6969
# 6821
# 5760
# 5614
# 7091
# 5698
# 5169
# 7294
# 5318
# 5368
# 6923
# 5463
# 5265
# 6321
# 5226
# 6868
# 4967
# 5293
# 5865
# 5841
# 5526
# 6852
# 6469
# 6168
# 7292
# 5036
# 5644
# 6856
# 5428
# 5027
# 4989
# 5221
# 6402
# 5346
# 6748

# %%
# Another way
with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    results = connection.execute(query)
    for row in results:
        print(row.loan_id)
# Out:
# 5314
# 5316
# 6863
# 5325
# 7240
# 6687
# 7284
# 6111
# 7235
# 5997
# 7121
# 6077
# 6228
# 6356
# 5523
# 6456
# 7104
# 6820
# 6876
# 7097
# 4959
# 6499
# 5479
# 5170
# 6721
# 7259
# 5285
# 5189
# 6650
# 7226
# 6087
# 7262
# 5519
# 6577
# 6509
# 6520
# 6699
# 6336
# 7055
# 6103
# 6202
# 7066
# 6696
# 6072
# 5130
# 5568
# 6678
# 6998
# 6580
# 6316
# 6512
# 6407
# 5002
# 6647
# 7137
# 6903
# 5918
# 6642
# 6210
# 6279
# 7249
# 6736
# 6112
# 5319
# 6596
# 5837
# 5657
# 5533
# 6232
# 6888
# 6066
# 5549
# 5060
# 6004
# 5126
# 7220
# 6668
# 5395
# 6836
# 6064
# 6919
# 6841
# 6038
# 6729
# 7198
# 6686
# 5836
# 7061
# 5595
# 5723
# 6120
# 6895
# 5882
# 5754
# 6594
# 6738
# 6624
# 6216
# 6229
# 5887
# 6808
# 6297
# 5161
# 5390
# 6150
# 6223
# 5032
# 6253
# 6460
# 6645
# 5176
# 5269
# 5351
# 5861
# 5450
# 7142
# 6306
# 6272
# 5044
# 5576
# 7192
# 5739
# 6526
# 5624
# 6244
# 5131
# 6960
# 6358
# 5418
# 6598
# 5464
# 6591
# 5724
# 6315
# 5876
# 6986
# 6294
# 5132
# 5877
# 6227
# 7241
# 6737
# 7004
# 6169
# 5208
# 6694
# 5599
# 6546
# 5414
# 5453
# 5740
# 5804
# 6745
# 6950
# 6996
# 5352
# 6151
# 5310
# 5045
# 6929
# 5151
# 5212
# 5138
# 5713
# 6704
# 6474
# 6676
# 6965
# 6725
# 7166
# 7138
# 5970
# 6157
# 6153
# 5693
# 5922
# 5959
# 5980
# 6764
# 5237
# 6726
# 6933
# 5145
# 7008
# 7227
# 6600
# 6712
# 7057
# 7176
# 7304
# 6362
# 5880
# 6535
# 5449
# 6342
# 5409
# 6955
# 6985
# 5125
# 5805
# 6185
# 7243
# 6403
# 6578
# 5413
# 6949
# 6545
# 6178
# 5160
# 6785
# 6540
# 6589
# 5900
# 5999
# 6043
# 5482
# 7263
# 6013
# 5750
# 6027
# 6303
# 7213
# 6659
# 6175
# 5610
# 5563
# 5989
# 6698
# 5312
# 7189
# 6816
# 6137
# 5128
# 5470
# 5593
# 5350
# 6063
# 6501
# 5452
# 4961
# 4973
# 6190
# 6715
# 5892
# 6550
# 5706
# 5148
# 6734
# 6109
# 6961
# 6810
# 5494
# 5311
# 5445
# 5301
# 7034
# 6751
# 6667
# 6130
# 5429
# 5725
# 6019
# 6421
# 6992
# 5136
# 5337
# 5495
# 7013
# 6012
# 6471
# 6296
# 7305
# 6144
# 6283
# 7246
# 5088
# 5988
# 5282
# 5938
# 5606
# 5385
# 6865
# 5586
# 6302
# 7194
# 6461
# 6732
# 6613
# 7036
# 5897
# 6995
# 5415
# 7136
# 7271
# 5375
# 5635
# 6817
# 5923
# 5329
# 6644
# 6354
# 5082
# 6585
# 6921
# 5366
# 5886
# 5741
# 4996
# 6015
# 6309
# 6073
# 6006
# 5611
# 6944
# 7101
# 6599
# 6940
# 5209
# 5388
# 6011
# 5591
# 7154
# 7130
# 6818
# 5625
# 6805
# 7233
# 7308
# 5895
# 7122
# 6173
# 6142
# 5358
# 6095
# 6878
# 6554
# 6793
# 7286
# 6076
# 5134
# 5419
# 6255
# 5656
# 6934
# 6028
# 6490
# 6415
# 7087
# 5420
# 5977
# 6824
# 5207
# 7115
# 7250
# 6010
# 6088
# 5682
# 7201
# 6938
# 6875
# 5953
# 5942
# 5382
# 6377
# 5931
# 5992
# 5790
# 6753
# 6562
# 7046
# 5868
# 5784
# 5878
# 5110
# 5210
# 7230
# 5005
# 6871
# 5363
# 7253
# 6055
# 5072
# 6913
# 6386
# 5634
# 5758
# 6819
# 7088
# 5039
# 5532
# 6037
# 6322
# 6887
# 6660
# 5451
# 6014
# 5556
# 6346
# 5850
# 5940
# 7119
# 5253
# 6851
# 6695
# 6908
# 7255
# 5674
# 6278
# 5486
# 5174
# 6621
# 6313
# 6435
# 6970
# 6310
# 5932
# 6877
# 6763
# 7085
# 7049
# 6959
# 5214
# 6350
# 5063
# 5041
# 5086
# 6942
# 5270
# 6705
# 7051
# 6758
# 6249
# 5808
# 5377
# 5446
# 5856
# 4986
# 7001
# 6677
# 6665
# 5817
# 6984
# 6541
# 5117
# 6097
# 5389
# 7219
# 6338
# 6922
# 5367
# 5638
# 5830
# 5338
# 6007
# 6612
# 5718
# 6104
# 5229
# 6625
# 5206
# 5963
# 4990
# 6641
# 5369
# 6196
# 5236
# 5719
# 5643
# 7050
# 6355
# 6688
# 6239
# 5531
# 6113
# 7181
# 6118
# 7264
# 5343
# 5051
# 5779
# 6605
# 6655
# 6534
# 5681
# 6607
# 6242
# 7242
# 7277
# 6675
# 5398
# 5956
# 5731
# 6956
# 6437
# 5447
# 5973
# 6075
# 5281
# 5103
# 6468
# 7209
# 5584
# 4988
# 6502
# 5651
# 4962
# 5862
# 7199
# 6727
# 7279
# 6544
# 5933
# 6574
# 6399
# 7187
# 6353
# 5043
# 5469
# 5976
# 6059
# 5799
# 6147
# 6254
# 7100
# 7147
# 5909
# 7037
# 5782
# 6237
# 6552
# 7067
# 5320
# 5930
# 6486
# 5245
# 6643
# 5260
# 5569
# 7110
# 7139
# 6791
# 5360
# 5287
# 6553
# 7072
# 6044
# 5332
# 6866
# 6633
# 6926
# 6442
# 5889
# 5765
# 5124
# 5491
# 6730
# 7151
# 5140
# 7171
# 6568
# 6861
# 6855
# 7129
# 5384
# 6859
# 5772
# 5665
# 6495
# 5061
# 6948
# 5773
# 6052
# 6682
# 6083
# 6962
# 5158
# 6464
# 5172
# 5582
# 6136
# 6235
# 6508
# 4968
# 6632
# 7195
# 5525
# 6320
# 6766
# 6872
# 5906
# 7172
# 6571
# 5616
# 6312
# 6470
# 5147
# 5501
# 6436
# 5699
# 5313
# 6234
# 6569
# 7202
# 5683
# 5034
# 5435
# 5815
# 5589
# 6746
# 6790
# 6857
# 6450
# 7221
# 5527
# 5620
# 6215
# 7167
# 5823
# 6207
# 6932
# 5669
# 5154
# 7168
# 5585
# 7200
# 6539
# 5774
# 6357
# 5042
# 5015
# 5354
# 6054
# 7295
# 5365
# 6755
# 5991
# 7035
# 5893
# 7164
# 5304
# 5561
# 5520
# 5241
# 7096
# 6078
# 5046
# 5334
# 6969
# 6821
# 5760
# 5614
# 7091
# 5698
# 5169
# 7294
# 5318
# 5368
# 6923
# 5463
# 5265
# 6321
# 5226
# 6868
# 4967
# 5293
# 5865
# 5841
# 5526
# 6852
# 6469
# 6168
# 7292
# 5036
# 5644
# 6856
# 5428
# 5027
# 4989
# 5221
# 6402
# 5346
# 6748

# %% [markdown]
# #### Getting the first column in a list

# %% [markdown]
# We can call the `.all()` method after the `.scalars()` method.

# %%
with engine.connect() as connection:
    query = text('SELECT * FROM loan')
    result = connection.execute(query)
    print(result.scalars().all())
# Out:
# [5314, 5316, 6863, 5325, 7240, 6687, 7284, 6111, 7235, 5997, 7121, 6077, 6228, 6356, 5523, 6456, 7104, 6820, 6876, 7097, 4959, 6499, 5479, 5170, 6721, 7259, 5285, 5189, 6650, 7226, 6087, 7262, 5519, 6577, 6509, 6520, 6699, 6336, 7055, 6103, 6202, 7066, 6696, 6072, 5130, 5568, 6678, 6998, 6580, 6316, 6512, 6407, 5002, 6647, 7137, 6903, 5918, 6642, 6210, 6279, 7249, 6736, 6112, 5319, 6596, 5837, 5657, 5533, 6232, 6888, 6066, 5549, 5060, 6004, 5126, 7220, 6668, 5395, 6836, 6064, 6919, 6841, 6038, 6729, 7198, 6686, 5836, 7061, 5595, 5723, 6120, 6895, 5882, 5754, 6594, 6738, 6624, 6216, 6229, 5887, 6808, 6297, 5161, 5390, 6150, 6223, 5032, 6253, 6460, 6645, 5176, 5269, 5351, 5861, 5450, 7142, 6306, 6272, 5044, 5576, 7192, 5739, 6526, 5624, 6244, 5131, 6960, 6358, 5418, 6598, 5464, 6591, 5724, 6315, 5876, 6986, 6294, 5132, 5877, 6227, 7241, 6737, 7004, 6169, 5208, 6694, 5599, 6546, 5414, 5453, 5740, 5804, 6745, 6950, 6996, 5352, 6151, 5310, 5045, 6929, 5151, 5212, 5138, 5713, 6704, 6474, 6676, 6965, 6725, 7166, 7138, 5970, 6157, 6153, 5693, 5922, 5959, 5980, 6764, 5237, 6726, 6933, 5145, 7008, 7227, 6600, 6712, 7057, 7176, 7304, 6362, 5880, 6535, 5449, 6342, 5409, 6955, 6985, 5125, 5805, 6185, 7243, 6403, 6578, 5413, 6949, 6545, 6178, 5160, 6785, 6540, 6589, 5900, 5999, 6043, 5482, 7263, 6013, 5750, 6027, 6303, 7213, 6659, 6175, 5610, 5563, 5989, 6698, 5312, 7189, 6816, 6137, 5128, 5470, 5593, 5350, 6063, 6501, 5452, 4961, 4973, 6190, 6715, 5892, 6550, 5706, 5148, 6734, 6109, 6961, 6810, 5494, 5311, 5445, 5301, 7034, 6751, 6667, 6130, 5429, 5725, 6019, 6421, 6992, 5136, 5337, 5495, 7013, 6012, 6471, 6296, 7305, 6144, 6283, 7246, 5088, 5988, 5282, 5938, 5606, 5385, 6865, 5586, 6302, 7194, 6461, 6732, 6613, 7036, 5897, 6995, 5415, 7136, 7271, 5375, 5635, 6817, 5923, 5329, 6644, 6354, 5082, 6585, 6921, 5366, 5886, 5741, 4996, 6015, 6309, 6073, 6006, 5611, 6944, 7101, 6599, 6940, 5209, 5388, 6011, 5591, 7154, 7130, 6818, 5625, 6805, 7233, 7308, 5895, 7122, 6173, 6142, 5358, 6095, 6878, 6554, 6793, 7286, 6076, 5134, 5419, 6255, 5656, 6934, 6028, 6490, 6415, 7087, 5420, 5977, 6824, 5207, 7115, 7250, 6010, 6088, 5682, 7201, 6938, 6875, 5953, 5942, 5382, 6377, 5931, 5992, 5790, 6753, 6562, 7046, 5868, 5784, 5878, 5110, 5210, 7230, 5005, 6871, 5363, 7253, 6055, 5072, 6913, 6386, 5634, 5758, 6819, 7088, 5039, 5532, 6037, 6322, 6887, 6660, 5451, 6014, 5556, 6346, 5850, 5940, 7119, 5253, 6851, 6695, 6908, 7255, 5674, 6278, 5486, 5174, 6621, 6313, 6435, 6970, 6310, 5932, 6877, 6763, 7085, 7049, 6959, 5214, 6350, 5063, 5041, 5086, 6942, 5270, 6705, 7051, 6758, 6249, 5808, 5377, 5446, 5856, 4986, 7001, 6677, 6665, 5817, 6984, 6541, 5117, 6097, 5389, 7219, 6338, 6922, 5367, 5638, 5830, 5338, 6007, 6612, 5718, 6104, 5229, 6625, 5206, 5963, 4990, 6641, 5369, 6196, 5236, 5719, 5643, 7050, 6355, 6688, 6239, 5531, 6113, 7181, 6118, 7264, 5343, 5051, 5779, 6605, 6655, 6534, 5681, 6607, 6242, 7242, 7277, 6675, 5398, 5956, 5731, 6956, 6437, 5447, 5973, 6075, 5281, 5103, 6468, 7209, 5584, 4988, 6502, 5651, 4962, 5862, 7199, 6727, 7279, 6544, 5933, 6574, 6399, 7187, 6353, 5043, 5469, 5976, 6059, 5799, 6147, 6254, 7100, 7147, 5909, 7037, 5782, 6237, 6552, 7067, 5320, 5930, 6486, 5245, 6643, 5260, 5569, 7110, 7139, 6791, 5360, 5287, 6553, 7072, 6044, 5332, 6866, 6633, 6926, 6442, 5889, 5765, 5124, 5491, 6730, 7151, 5140, 7171, 6568, 6861, 6855, 7129, 5384, 6859, 5772, 5665, 6495, 5061, 6948, 5773, 6052, 6682, 6083, 6962, 5158, 6464, 5172, 5582, 6136, 6235, 6508, 4968, 6632, 7195, 5525, 6320, 6766, 6872, 5906, 7172, 6571, 5616, 6312, 6470, 5147, 5501, 6436, 5699, 5313, 6234, 6569, 7202, 5683, 5034, 5435, 5815, 5589, 6746, 6790, 6857, 6450, 7221, 5527, 5620, 6215, 7167, 5823, 6207, 6932, 5669, 5154, 7168, 5585, 7200, 6539, 5774, 6357, 5042, 5015, 5354, 6054, 7295, 5365, 6755, 5991, 7035, 5893, 7164, 5304, 5561, 5520, 5241, 7096, 6078, 5046, 5334, 6969, 6821, 5760, 5614, 7091, 5698, 5169, 7294, 5318, 5368, 6923, 5463, 5265, 6321, 5226, 6868, 4967, 5293, 5865, 584 ...

# %% [markdown]
# ### Using SQLAlchemy as an ORM

# %% [markdown]
# The idea behind ORM (object-relational mapping) is to create a code representation of your database using classes and objects instead of writing raw SQL statements. The classes represent the tables in your database, and the objects of those classes represent rows. So the first step to using ORM is to define classes that map to your tables. Classes that represent tables in an ORM are called models.

# %% [markdown]
# We won't be diving into it during the bootcamp, but feel free to [read the docs](https://docs.sqlalchemy.org/en/20/tutorial/) to learn how to use it!

# %% [markdown]
# ### More examples on raw queries

# %% [markdown]
# Let's get how many loans were granted every year, and the month of each duration.

# %%
with engine.connect() as connection:
    # Getting how many loans were granted every year, and the month of each duration.
    txt = '''select year(date) as 'Year', month(date) as 'Month', duration, count(loan_id) as 'New_loans' from bank.loan
            group by Year, Month, duration
            order by Year, Month, duration;'''
    query = text(txt)
    result = connection.execute(query)
    display(pd.DataFrame(result.all()))
# Out:
#      Year  Month  duration  New_loans
# 0    1993      7        12          1
# 1    1993      7        36          1
# 2    1993      7        60          1
# 3    1993      8        36          1
# 4    1993      9        12          1
# ..    ...    ...       ...        ...
# 271  1998     12        12          1
# 272  1998     12        24          2
# 273  1998     12        36          3
# 274  1998     12        48          1
# 275  1998     12        60          1
#
# [276 rows x 4 columns]

# %% [markdown]
# Let's create a function to do the same as above.

# %%
# Getting how many loans were granted every year, and the month of each duration.
def get_AB_loans(connection):
    with engine.connect() as connection:
        # Getting how many loans were granted every year, and the month of each duration.
        txt = '''select year(date) as 'Year', month(date) as 'Month', duration, count(loan_id) as 'New_loans' from bank.loan
                group by Year, Month, duration
                order by Year, Month, duration;'''
        query = text(txt)
        result = connection.execute(query)
        return pd.DataFrame(result.all())

# %%
get_AB_loans(connection)
# Out:
#      Year  Month  duration  New_loans
# 0    1993      7        12          1
# 1    1993      7        36          1
# 2    1993      7        60          1
# 3    1993      8        36          1
# 4    1993      9        12          1
# ..    ...    ...       ...        ...
# 271  1998     12        12          1
# 272  1998     12        24          2
# 273  1998     12        36          3
# 274  1998     12        48          1
# 275  1998     12        60          1
#
# [276 rows x 4 columns]

# %% [markdown]
# ## Summary

# %% [markdown]
# As you can see, launching queries from Python against a SQL database involves several steps:
#
# - Create the `engine`:
#     ```python
#     connection_string = 'dialect+driver://username:password@host:port/database'
#     engine = sqlalchemy.create_engine(connection_string)
#     ```
# - Getting a `connection`
#     ```python
#     with engine.connect() as connection:
#         ...
#     ```
# - Create a string with the query and put it inside `text()` method
# - Launch the query with `execute()` method
# - Get data from the Result object as needed
#
# For example, if we want the whole result from our `SELECT` query, we could do:
#
# ```python
# with engine.connect() as connection:
#     query = text('SELECT ...')
#     result = connection.execute(query)
#     df = pd.DataFrame(result.all())
#
# df # Do stuff with the DataFrame
# ```

# %% [markdown]
# Some guidelines when creating functions:
#
# - Try to make your functions as self contained as possible
# - Try to make your functions as general as possible (use optional arguments if needed)
# - Test your Python functions!

# %% [markdown]
# # Bonus: MySQL Connector

# %% [markdown]
# MySQL Connector/Python is an official MySQL client library for Python. It allows Python programs to connect and interact with MySQL databases.
#
# - Suitable for scripts or applications that need a straightforward way to connect to a MySQL database and execute queries.
# - Specific to MySQL.
# - Focused on providing a direct connection to MySQL, so while it's efficient for that purpose, it lacks the broader features and abstractions of an ORM like SQL Alchemy.
# - Operates at a lower level. You work directly with SQL queries, and the results you get back are typically in the form of rows and columns, rather than structured Python objects.

# %% [markdown]
# ## Installation:
# Before we start, ensure you have `mysql-connector-python` installed.
#
# If you're using conda as your package manager:
#
# ```bash
# conda install mysql-connector-python -y
# ```
#
# or if you're using pip as your package manager:
#
# ```bash
# pip install mysql-connector-python
# ```

# %%
# !conda install mysql-connector-python -y

# %% [markdown]
# ## Establishing a Connection:
# To connect to a MySQL database, you need the host name (or IP address), the database name, and the credentials (username and password).
#
# ```python
# import mysql.connector
#
# conn = mysql.connector.connect(
#     host="localhost",
#     user="your_username",
#     password="your_password",
#     database="your_database_name"
# )
# ```

# %%
import mysql.connector

# %%
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
#  ········

# %%
conn = mysql.connector.connect(host='localhost',
                        user='root',
                        passwd=password)

# %% [markdown]
# ## Creating a Cursor:
# A cursor object allows you to execute SQL queries and fetch results.
#
# ```python
# cursor = conn.cursor()
# ```

# %%
cursor = conn.cursor()

cursor

# %% [markdown]
# ## Executing SQL Queries:
# Using the cursor, you can execute any SQL statement.
#
# **SELECT Statement:**
#
# ```python
# cursor.execute("SELECT * FROM your_table_name")
# rows = cursor.fetchall()
#
# for row in rows:
#     print(row)
# ```
#
# **INSERT Statement:**
#
# ```python
# sql = "INSERT INTO your_table_name (column1, column2) VALUES (%s, %s)"
# values = ("value1", "value2")
#
# cursor.execute(sql, values)
# conn.commit()  # Save the changes
# ```
#
# **CREATE Statement:**
# ```python
# cursor.execute("CREATE DATABASE new_database_name")
# conn.commit()  # Save the changes
# ```

# %% [markdown]
# ### Example: CoffeeShop DB 📒☕
#
# We're going to use a simple, relatable example: setting up a database for a coffee shop.
#
# 1. **Create** our `CoffeeShop` database.
# 2. **Create** a table to list various coffee items (coffee id, coffee name, price).
# 3. **Insert** coffee menu items into our table.
# 4. **Query** our table to view the items we've added.

# %% [markdown]
# Let's create a CoffeeShop database.

# %%
# Create CoffeeShop Database
cursor.execute("CREATE DATABASE IF NOT EXISTS CoffeeShop")

# %%
# Switch to the CoffeeShop Database
cursor.execute("USE CoffeeShop")

# %% [markdown]
# Create a Menu Table: We'll create a table called Menu with columns for coffee name and its price.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Menu (
    coffee_id INT AUTO_INCREMENT PRIMARY KEY,
    coffee_name VARCHAR(255) NOT NULL,
    price DECIMAL(5,2) NOT NULL
)
""")
print("Table Menu created successfully!")
# Out:
# Table Menu created successfully!

# %% [markdown]
# Let's insert values into the table:

# %%
# Insert Coffee Items into Menu Table
menu_items = [
    ("Espresso", 2.50),
    ("Cappuccino", 3.00),
    ("Latte", 3.50),
    ("Americano", 2.00),
    ("Mocha", 3.75)
]

cursor.executemany("INSERT INTO Menu (coffee_name, price) VALUES (%s, %s)", menu_items)
conn.commit()
print(f"{cursor.rowcount} coffee items inserted!")
# Out:
# 5 coffee items inserted!

# %% [markdown]
# Finally, lets see our data!

# %%
# Select and Display Coffee Items from Menu Table
cursor.execute("SELECT coffee_name, price FROM Menu ORDER BY price DESC")
results = cursor.fetchall()

pd.DataFrame(results)
# Out:
#              0     1
# 0        Mocha  3.75
# 1        Mocha  3.75
# 2        Mocha  3.75
# 3        Latte  3.50
# 4        Latte  3.50
# 5        Latte  3.50
# 6   Cappuccino  3.00
# 7   Cappuccino  3.00
# 8   Cappuccino  3.00
# 9     Espresso  2.50
# 10    Espresso  2.50
# 11    Espresso  2.50
# 12   Americano  2.00
# 13   Americano  2.00
# 14   Americano  2.00

# %% [markdown]
# ## Closing the Connection:
# After performing database operations, remember to close the cursor and the connection.
#
# ```python
# cursor.close()
# conn.close()
# ```

# %%
# Close the cursor and the connection.
cursor.close()
conn.close()
